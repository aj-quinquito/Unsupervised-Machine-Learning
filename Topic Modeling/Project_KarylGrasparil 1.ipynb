# %% [markdown]
# # **Project: Topic Modelling**

# %% [markdown]
# - Karyl Abigail Grasparil

# %% [markdown]
# ## Executive Summary:
# In this project, I performed topic modeling on a dataset containing research papers categorized by subject, sourced from Kaggle. The objective was to identify hidden topics within the text data using two popular topic modeling techniques: LDA and NMF.
#
# The preprocessing phase involved cleaning and preparing the text data, which included standardizing case, removing stop words, lemmatizing, and tokenizing. Following this, I vectorized the data using various vectorization techniques (e.g., TF-IDF and CountVectorizer) to convert the text into numerical format.
#
# I developed six LDA and NMF models using different sets of hyperparameters to identify the optimal models. The models were evaluated based on metrics like perplexity, coherence scores, and topic-word distributions. I visualized the best LDA model using pyLDAvis for interactive exploration of topics.
#
# The results indicate that *[insert best model here]* performed better at extracting meaningful topics relevant to the use case. The findings from the best model are discussed in detail, with recommendations for further improvements. The outcomes are expected to benefit stakeholders by providing deeper insights into research trends and themes within academic publications.

# %% [markdown]
# ## Preprocssing:

# %% [markdown]
# Importing the libraries that will be used for the project

# %%
# Suppress warnings and import libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import re
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.metrics import mean_squared_error
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.metrics import log_loss
from sklearn.decomposition import NMF
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abiga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\abiga\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abiga\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Load the Dataset

# %%
# Load the dataset
df = pd.read_csv("arXiv-DataFrame.csv")
df.head()
# Out:
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\indexes\base.py:411: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\indexes\base.py:411: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\indexes\base.py:411: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\frame.py:655: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(IPython.__version__) < LooseVersion('3.0'):
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\frame.py:655: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(IPython.__version__) < LooseVersion('3.0'):
#    Unnamed: 0            id  \
# 0           0  cs/9308101v1
# 1           1  cs/9308102v1
# 2           2  cs/9309101v1
# 3           3  cs/9311101v1
# 4           4  cs/9311102v1
#
#                                                Title  \
# 0                               Dynamic Backtracking
# 1  A Market-Oriented Programming Environment and ...
# 2            An Empirical Analysis of Search in GSAT
# 3  The Difficulties of Learning Logic Programs wi...
# 4  Software Agents: Completing Patterns and Const...
#
#                                              Summary           Author  \
# 0  Because of their occasional need to return to ...   M. L. Ginsberg
# 1  Market price systems constitute a well-underst...    M. P. Wellman
# 2  We describe an extensive study of search in GS...       I. P. Gent
# 3  As real logic programmers normally use cut (!)...     F. Bergadano
# 4  To support the goal of allowing users to recor...  J. C. Schlimmer
#
#                                 Link          Publish Date  \
# 0  http://arxiv.org/pdf/cs/9308101v1  1993-08-01T00:00:00Z
# 1  http://arxiv.org/pdf/cs/9308102v1  1993-08-01T00:00:00Z
# 2  http://arxiv.org/pdf/cs/9309101v1  1993-09-01T00:00:00Z
# 3  http://arxiv.org/pdf/cs/9311101v1  1993-11-01T00:00:00Z
# 4  http://arxiv.org/pdf/cs/9311102v1  1993-11-01T00:00:00Z
#
#             Update Date Primary Category   Category
# 0  1993-08-01T00:00:00Z            cs.AI  ['cs.AI']
# 1  1993-08-01T00:00:00Z            cs.AI  ['cs.AI']
# 2  1993-09-01T00:00:00Z            cs.AI  ['cs.AI']
# 3  1993-11-01T00:00:00Z            cs.AI  ['cs.AI']
# 4  1993-11-01T00:00:00Z            cs.AI  ['cs.AI']

# %% [markdown]
# Data Preprocessing

# %%
df = df["Summary"].tolist()
print("Summary:\n{lines}\n".format(lines=df[:5]))
print("LENGTH:\n{length}\n".format(length=len(df)))
# Out:
# Summary:
# ['Because of their occasional need to return to shallow points in a search tree, existing backtracking methods can sometimes erase meaningful progress toward solving a search problem. In this paper, we present a method by which backtrack points can be moved deeper in the search space, thereby avoiding this difficulty. The technique developed is a variant of dependency-directed backtracking that uses only polynomial space while still providing useful control information and retaining the completeness guarantees provided by earlier approaches.', 'Market price systems constitute a well-understood class of mechanisms that under certain conditions provide effective decentralization of decision making with minimal communication overhead. In a market-oriented programming approach to distributed problem solving, we derive the activities and resource allocations for a set of computational agents by computing the competitive equilibrium of an artificial economy. WALRAS provides basic constructs for defining computational market structures, and protocols for deriving their corresponding price equilibria. In a particular realization of this approach for a form of multicommodity flow problem, we see that careful construction of the decision process according to economic principles can lead to efficient distributed resource allocation, and that the behavior of the system can be meaningfully analyzed in economic terms.', "We describe an extensive study of search in GSAT, an approximation procedure for propositional satisfiability. GSAT performs greedy hill-climbing on the number of satisfied clauses in a truth assignment. Our experiments provide a more complete picture of GSAT's search than previous accounts. We describe in detail the two phases of search: rapid hill-climbing followed by a long plateau search. We demonstrate that when applied to randomly generated 3SAT problems, there is a very simple scaling with problem size for both the mean number of satisfied clauses and the mean branching rate. Our results allow us to make detailed numerical conjectures about the length of the hill-climbing phase, the average gradient of this phase, and to conjecture that both the average score and average branching rate decay exponentially during plateau search. We end by showing how these results can be used to direct future theoretical analysis. This work provides a case study of how computer experiments can be used to improve understanding of the theoretical properties of algorithms.", 'As real logic programmers normally use cut (!), an effective learning procedure for logic programs should be able to deal with it. Because the cut predicate has only a procedural meaning, clauses containing cut cannot be learned using an extensional evaluation method, as is done in most learning systems. On the other hand, searching a space of possible programs (instead of a space of independent clauses) is unfeasible. An alternative solution is to generate first a candidate base program which covers the positive examples, and then make it consistent by inserting cut where appropriate. The problem of learning programs with cut has not been investigated before and this seems to be a natural and reasonable approach. We generalize this scheme and investigate the difficulties that arise. Some of the major shortcomings are actually caused, in general, by the need for intensional evaluation. As a conclusion, the analysis of this paper suggests, on precise and technical grounds, that learning cut is difficult, and current induction techniques should probably be restricted to purely declarative logic languages.', "To support the goal of allowing users to record and retrieve information, this paper describes an interactive note-taking system for pen-based computers with two distinctive features. First, it actively predicts what the user is going to write. Second, it automatically constructs a custom, button-box user interface on request. The system is an example of a learnin ...
#
# LENGTH:
# 53474

# %%
# Convert all text to lowercase
df = [text.lower() for text in df]

# Remove special characters, numbers, and extra spaces
df = [re.sub(r'[^a-z\s]', '', text) for text in df]

# Tokenization
df = [word_tokenize(text) for text in df]

# Initialize lemmatizer and stop words
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Define a preprocessing function
def preprocess(text):
    return [lemmatizer.lemmatize(word) for word in text if word not in stop_words and len(word) > 2]

# Apply preprocessing function to each summary
df = [preprocess(tokens) for tokens in df]

# Join tokens back into a single string for each summary
df = [' '.join(tokens) for tokens in df]

# Display the cleaned summaries
print("Processed Summary:\n{lines}\n".format(lines=df[:5]))
print("LENGTH:\n{length}\n".format(length=len(df)))
# Out:
# Processed Summary:
# ['occasional need return shallow point search tree existing backtracking method sometimes erase meaningful progress toward solving search problem paper present method backtrack point moved deeper search space thereby avoiding difficulty technique developed variant dependencydirected backtracking us polynomial space still providing useful control information retaining completeness guarantee provided earlier approach', 'market price system constitute wellunderstood class mechanism certain condition provide effective decentralization decision making minimal communication overhead marketoriented programming approach distributed problem solving derive activity resource allocation set computational agent computing competitive equilibrium artificial economy walras provides basic construct defining computational market structure protocol deriving corresponding price equilibrium particular realization approach form multicommodity flow problem see careful construction decision process according economic principle lead efficient distributed resource allocation behavior system meaningfully analyzed economic term', 'describe extensive study search gsat approximation procedure propositional satisfiability gsat performs greedy hillclimbing number satisfied clause truth assignment experiment provide complete picture gsats search previous account describe detail two phase search rapid hillclimbing followed long plateau search demonstrate applied randomly generated sat problem simple scaling problem size mean number satisfied clause mean branching rate result allow make detailed numerical conjecture length hillclimbing phase average gradient phase conjecture average score average branching rate decay exponentially plateau search end showing result used direct future theoretical analysis work provides case study computer experiment used improve understanding theoretical property algorithm', 'real logic programmer normally use cut effective learning procedure logic program able deal cut predicate procedural meaning clause containing cut learned using extensional evaluation method done learning system hand searching space possible program instead space independent clause unfeasible alternative solution generate first candidate base program cover positive example make consistent inserting cut appropriate problem learning program cut investigated seems natural reasonable approach generalize scheme investigate difficulty arise major shortcoming actually caused general need intensional evaluation conclusion analysis paper suggests precise technical ground learning cut difficult current induction technique probably restricted purely declarative logic language', 'support goal allowing user record retrieve information paper describes interactive notetaking system penbased computer two distinctive feature first actively predicts user going write second automatically construct custom buttonbox user interface request system example learningapprentice software agent machine learning component characterizes syntax semantics user information performance system us learned information generate completion string construct user interface description online appendix people like record information paper initially efficient lack flexibility recording information computer le efficient powerful new note taking softwre user record information directly computer behind interface agent act user help provides default construct custom user interface demonstration quicktime movie note taking agent action file binhexed selfextracting archive macintosh utility binhex available macarchiveumichedu quicktime available ftpapplecom dtsmacsyssoftquicktime']
#
# LENGTH:
# 53474

# %% [markdown]
# ## Models

# %% [markdown]
# Vectorization

# %%
# Vectorize using CountVectorizer for LDA
count_vectorizer = CountVectorizer(max_df=0.9, min_df=10)
count_data = count_vectorizer.fit_transform(df) 

# Vectorize using TF-IDF for NMF
tfidf_vectorizer = TfidfVectorizer(max_df=0.9, min_df=10)
tfidf_data = tfidf_vectorizer.fit_transform(df)

# %%
# Define the function to reformat output matrices into readable tables
def get_topics(mod, vec, names, docs, ndocs, nwords):
    # Word to topic matrix
    W = mod.components_
    W_norm = W / W.sum(axis=1)[:, np.newaxis]
    # Topic to document matrix
    H = mod.transform(vec)
    
    W_dict = {}
    H_dict = {}
    
    for tpc_idx, tpc_val in enumerate(W_norm):
        topic = f"Topic{tpc_idx + 1}"
        
        # Formatting W (Word-Topic)
        W_indices = tpc_val.argsort()[::-1][:nwords]
        W_names_values = [(round(tpc_val[j], 4), names[j]) for j in W_indices]
        W_dict[topic] = W_names_values
        
        # Formatting H (Document-Topic)
        H_indices = H[:, tpc_idx].argsort()[::-1][:ndocs]
        H_names_values = [(round(H[:, tpc_idx][j], 4), docs[j]) for j in H_indices]
        H_dict[topic] = H_names_values
        
    # Convert to DataFrames
    W_df = pd.DataFrame(W_dict, index=[f"Word{i+1}" for i in range(nwords)])
    H_df = pd.DataFrame(H_dict, index=[f"Doc{i+1}" for i in range(ndocs)])
        
    return W_df, H_df

# %% [markdown]
# Train and Evaluate LDA Models with Different Hyperparameters

# %%
# Function to train and evaluate multiple LDA models with alpha and beta parameters
def train_lda_models(data, vectorizer, docs, num_topics_list, alpha=None, beta=None, ndocs=5, nwords=10):
    """
    Train and evaluate LDA models with specified parameters, displaying word-topic and document-topic tables for all models.
    """
    results = []
    feature_names = vectorizer.get_feature_names_out()
    
    for num_topics in num_topics_list:
        print(f"\nTraining LDA with {num_topics} topics, alpha={alpha}, beta={beta}...")
        lda = LatentDirichletAllocation(
            n_components=num_topics,
            random_state=42,
            max_iter=10,
            doc_topic_prior=alpha,  # Alpha parameter
            topic_word_prior=beta   # Beta parameter
        )
        lda.fit(data)
        
        # Calculate perplexity
        perplexity = lda.perplexity(data)
        print(f"Perplexity for LDA with {num_topics} topics: {perplexity:.4f}")
        
        # Generate word-topic and document-topic tables
        W_df, H_df = get_topics(lda, data, feature_names, docs, ndocs, nwords)
        
        # Display the tables for the current model
        print("\nWord-Topic Table:")
        print(W_df)
        print("\nDocument-Topic Table:")
        print(H_df)
        
        # Store the model's evaluation results
        results.append({
            "num_topics": num_topics,
            "model": lda,
            "perplexity": perplexity,
            "word_topic_table": W_df,
            "doc_topic_table": H_df
        })
    
    return results

# Train and evaluate LDA models with alpha and beta
num_topics_list_lda = [15, 20, 25, 30]
docs = df

# Alpha and Beta Parameters
alpha = 0.5  # Balances sparsity and density
beta = 0.1   # Balances sparsity and density

# Train LDA models and evaluate them
lda_results = train_lda_models(count_data, count_vectorizer, docs, num_topics_list_lda, alpha=alpha, beta=beta)

# Select the best model based on perplexity
best_lda_model = min(lda_results, key=lambda x: x["perplexity"])

# Display the best model's results
print("\nBest LDA Model:")
print(f"Number of Topics: {best_lda_model['num_topics']}")
print(f"Perplexity: {best_lda_model['perplexity']:.4f}")
print("\nWord-Topic Table for Best Model:")
print(best_lda_model["word_topic_table"])
print("\nDocument-Topic Table for Best Model:")
print(best_lda_model["doc_topic_table"])
# Out:
# Training LDA with 15 topics, alpha=0.5, beta=0.1...
# Perplexity for LDA with 15 topics: 2324.4677
#
# Word-Topic Table:
#                     Topic1              Topic2              Topic3  \
# Word1     (0.0153, energy)    (0.0667, system)     (0.0179, graph)
# Word2       (0.0118, mass)   (0.0258, control)  (0.0168, function)
# Word3      (0.0098, model)     (0.0221, power)    (0.0136, number)
# Word4   (0.0092, spectrum)     (0.017, design)     (0.0132, bound)
# Word5       (0.0082, star)     (0.0102, paper)   (0.0115, lattice)
# Word6     (0.0061, galaxy)  (0.0097, proposed)      (0.011, model)
# Word7   (0.0057, emission)     (0.009, energy)    (0.0109, result)
# Word8    (0.0056, cluster)     (0.0083, state)      (0.0081, show)
# Word9     (0.0055, result)   (0.0073, circuit)    (0.0081, random)
# Word10      (0.0055, data)     (0.0071, based)      (0.0078, tree)
#
#                     Topic4                  Topic5                 Topic6  \
# Word1     (0.0298, method)     (0.0487, algorithm)     (0.0109, research)
# Word2      (0.0139, model)       (0.0335, problem)        (0.0094, paper)
# Word3      (0.0118, image)          (0.0139, time)         (0.0063, year)
# Word4       (0.011, based)        (0.0121, method)      (0.0063, science)
# Word5       (0.011, using)         (0.011, matrix)  (0.0063, development)
# Word6   (0.0107, proposed)       (0.0099, optimal)         (0.006, study)
# Word7   (0.0106, approach)   (0.0093, performance)          (0.0057, new)
# Word8     (0.0102, result)  (0.0091, optimization)       (0.0053, social)
# Word9     (0.01, learning)      (0.0086, approach)       (0.0051, physic)
# Word10   (0.0093, feature)          (0.0079, show)      (0.0049, student)
#
#                        Topic7                 Topic8                 Topic9  \
# Word1          (0.0179, data)      (0.0387, quantum)         (0.0212, cell)
# Word2          (0.0122, user)       (0.0318, system)        (0.0177, model)
# Word3   (0.0112, application)        (0.0297, state)      (0.0108, protein)
# Word4          (0.0093, code)      (0.0251, channel)         (0.0069, gene)
# Word5   (0.0086, information)        (0.0097, field)      (0.0067, process)
# Word6         (0.0086, paper)     (0.0097, particle)     (0.006, mechanism)
# Word7        (0.0083, system)     (0.009, classical)      (0.0059, dynamic)
# Word8      (0.0071, software)     (0.0084, capacity)    (0.0054, molecular)
# Word9          (0.0062, tool)  (0.0084, information)  (0.0053, interaction)
# Word10       (0.006, network)          (0.0083, two)     (0.0053, molecule)
#
#                        Topic10                Topic11              Topic12  \
# Word1          (0.0314, model)        (0.0121, field)     (0.0192, theory)
# Word2   (0.0194, distribution)     (0.0098, magnetic)    (0.0182, network)
# Word3           (0.0168, data)        (0.0083, phase)    (0.0137, dynamic)
# Word4         (0.0154, method)      (0.0083, surface)      (0.0105, agent)
# Word5        (0.0137, network)  (0.0072, temperature)   (0.0084, behavior)
# Word6      (0.0121, parameter)        (0.007, effect)       (0.008, model)
# Word7          (0.0083, error)    (0.0066, frequency)  (0.0073, structure)
# Word8       (0.0082, estimate)     (0.0061, electron)    (0.0068, pattern)
# Word9     (0.0078, estimation)          (0.006, wave)   (0.0064, analysis)
# Word10   (0.0077, probability)          (0.006, mode)      (0.0063, study)
#
#                   Topic13              Topic14                 Topic15
# Word1     (0.0184, space)      (0.0184, model)      (0.0343, equation)
# Word2     (0.0176, group)      (0.016, market)       (0.022, solution)
# Word3        (0.011, set)      (0.0126, price)         (0.0126, model)
# Word4   (0.0109, algebra)       (0.0116, risk)     (0.0107, nonlinear)
# Word5    (0.0096, result)       (0.0091, game)        (0.0098, method)
# Word6     (0.0094, class)   (0.0089, strategy)        (0.0094, theory)
# Word7     (0.0088, prove)        (0.008, show)     (0.0086, numerical)
# Word8      (0.0087, show)       (0.0069, time)  (0.0082, differential)
# Word9     (0.0086, paper)    (0.0064, process)          (0.008, field)
# Word10  (0.0083, theorem)  (0.0063, financial)          (0.0072, case)
#
# Document-Topic Table:
#                                                  Topic1  \
# Doc1  (0.9421, discus xray property radio source det...
# Doc2  (0.9392, model disk galaxy formation commonly ...
# Doc3  (0.9391, present high resolution measurement n...
# Doc4  (0.9384, black hole binary transient undergo d...
# Doc5  (0.9383, compare spectral property short long ...
#
#                                                  Topic2  \
# Doc1  (0.889, paper low power low area array multipl...
# Doc2  (0.8704, onchip voltage regulation using distr...
# Doc3  (0.8684, paper proposes lowpower energy effici...
# Doc4  (0.8553, ieee ongoing revision ieee floating p...
# Doc5  (0.8448, considering control problem nonlinear...
#
#                                                  Topic3  \
# Doc1  (0.8657, total coloring graph coloring vertex ...
# Doc2  (0.8605, study dynamical property random trans...
# Doc3  (0.8461, study numerically paramagnetic phase ...
# Doc4  (0.8399, investigate localization two interact...
# Doc5  (0.832, new graphical method developed calcula...
#
#                                                  Topic4  \
# Doc1  (0.9278, utterance contains speech multiple la...
# Doc2  (0.9263, propose method zeroresource domain ad...
# Doc3  (0.9253, work propose new approach language id...
# Doc4  (0.9236, investigate novel crosslingual multis...
# Doc5  (0.9213, speaker recognition performance emoti...
#
#                                                  Topic5  \
# Doc1  (0.8684, paper present analyze new set lowrank...
# Doc2  (0.8625, novel algorithm proposed candecomppar...
# Doc3  (0.8493, matrix tensor completion aim recover ...
# Doc4  (0.8474, recent study sparse modeling nonconve...
# Doc5  (0.8405, attractiveness canonical polyadic ten...
#
#                                                  Topic6  \
# Doc1  (0.9405, leo goodman born august new york city...
# Doc2  (0.9194, george roussas born city marmara cent...
# Doc3  (0.9179, tadeusz calinski born poznan poland d...
# Doc4  (0.909, present two program address need bette...
# Doc5  (0.9053, harry martz born june grew cumberland...
#
#                                                  Topic7  \
# Doc1  (0.9185, grid based system require database ac...
# Doc2  (0.9126, pool project common persistency frame...
# Doc3  (0.9097, paper introduces writeoncereadmany xm...
# Doc4  (0.8978, information retrieval distributed het...
# Doc5  (0.897, alien alice environment gridlike syste...
#
#                                                  Topic8  \
# Doc1  (0.8915, wideband fading channel considered ca...
# Doc2  (0.8915, wideband fading channel considered ca...
# Doc3  (0.8128, multiple transmit antenna downlink ch...
# Doc4  (0.8128, multiple transmit antenna downlink ch...
# Doc5  (0.8066, shown mutual information curve coded ...
#
#                                                  Topic9  \
# Doc1  (0.9367, experimental evidence suggests foldin...
# Doc2  (0.921, kinesin motor protein destabilize micr...
# Doc3  (0.9208, zincfingers widely exist eukaryotic c...
# Doc4  (0.9162, development tumor known result accumu...
# Doc5  (0.9159, leishmania lipophosphoglycan molecule...
#
#                                                 Topic10  \
# Doc1  (0.9128, consider class semiparametric regress...
# Doc2  (0.9128, consider class semiparametric regress...
# Doc3  (0.9034, consider inference procedure conditio...
# Doc4  (0.8952, wang tchetgen tchetgen studied identi...
# Doc5  (0.8918, paper considers panel data model cond...
#
#                                                 Topic11  \
# Doc1  (0.9163, analysis alfven wave generation assoc...
# Doc2  (0.9113, paper examine suprathermal ion measur...
# Doc3  (0.9107, recent result van allen probe mission...
# Doc4  (0.9088, present first observation large ampli...
# Doc5  (0.9037, convection inside magnetosphere regar...
#
#                                                 Topic12  \
# Doc1  (0.8656, present study focused effect trunk ex...
# Doc2  (0.8198, many complex human natural phenomenon...
# Doc3  (0.7926, aim present study ass effect plantarf...
# Doc4  (0.7921, purpose present experiment investigat...
# Doc5  (0.7482, separate study reported postural cont...
#
#                                                 Topic13  \
# Doc1  (0.948, hausdorff topological group gtau calle...
# Doc2  (0.942, prove algebraic hypersurfaces defined ...
# Doc3  (0.9354, topological group gmu class mathcal m...
# Doc4  (0.9299, thesis develop cohomology diagram alg...
# Doc5  (0.9291, previous work citeas showed attach po...
#
#                                                 Topic14  \
# Doc1  (0.9064, propose model credit market random de...
# Doc2  (0.9003, develop finite horizon continuous tim...
# Doc3  (0.8983, study robust double auction mechanism...
# Doc4  (0.8879, study impact central clearing overthe...
# Doc5  (0.8801, consider partially asymmetric threepl...
#
#                                                 Topic15
# Doc1  (0.8645, present special solution discrete pai...
# Doc2  (0.8446, advection equation basis mathematical...
# Doc3  (0.8441, socalled direct approach separation v...
# Doc4  (0.8404, study class quadratically nonlinear w...
# Doc5  (0.8382, extending clarksonkruskals direct sim...
#
# Training LDA with 20 topics, alpha=0.5, beta=0.1...
# Perplexity for LDA with 20 topics: 2358.3664
#
# Word-Topic Table:
#                        Topic1               Topic2              Topic3  \
# Word1         (0.022, energy)     (0.0927, system)  (0.0257, function)
# Word2          (0.0149, mass)    (0.0294, control)      (0.025, graph)
# Word3       (0.013, spectrum)      (0.0214, state)    (0.0189, number)
# Word4        (0.0093, source)      (0.0201, bound)   (0.0183, problem)
# Word5      (0.0085, emission)       (0.0142, time)     (0.0129, point)
# Word6          (0.0069, line)  (0.0119, automaton)      (0.0114, tree)
# Word7         (0.0069, model)     (0.0103, linear)    (0.0113, result)
# Word8          (0.0064, xray)   (0.0098, proposed)       (0.0105, set)
# Word9   (0.0059, measurement)      (0.0096, paper)   (0.0104, lattice)
# Word10     (0.0059, detector)   (0.0093, protocol)    (0.0104, random)
#
#                     Topic4                  Topic5                Topic6  \
# Word1     (0.0426, method)     (0.0489, algorithm)    (0.0135, research)
# Word2      (0.0138, model)       (0.0372, problem)       (0.0096, paper)
# Word3    (0.013, proposed)       (0.0178, optimal)     (0.0083, science)
# Word4      (0.0119, based)          (0.0163, time)      (0.0069, physic)
# Word5      (0.0117, using)  (0.0127, optimization)     (0.0065, student)
# Word6     (0.0116, signal)      (0.0105, approach)       (0.0061, study)
# Word7   (0.0115, approach)   (0.0098, performance)     (0.0061, article)
# Word8    (0.0112, feature)          (0.0092, show)        (0.0061, year)
# Word9   (0.0111, learning)        (0.0084, result)  (0.006, development)
# Word10    (0.0096, result)        (0.0082, method)         (0.0059, new)
#
#                        Topic7                    Topic8                Topic9  \
# Word1         (0.0226, image)           (0.0357, group)     (0.0154, cluster)
# Word2          (0.0216, data)         (0.0326, algebra)   (0.0145, structure)
# Word3          (0.0174, code)          (0.027, quantum)       (0.0104, model)
# Word4     (0.0174, algorithm)  (0.0221, representation)    (0.0089, molecule)
# Word5   (0.0112, information)         (0.0213, channel)     (0.0089, protein)
# Word6     (0.0075, technique)           (0.0136, field)  (0.0087, functional)
# Word7         (0.0073, paper)         (0.0124, element)    (0.0086, property)
# Word8         (0.0072, query)            (0.0117, type)      (0.0086, energy)
# Word9        (0.0067, search)             (0.0114, lie)   (0.0084, molecular)
# Word10   (0.0066, complexity)            (0.0112, ring)       (0.0083, logic)
#
#                        Topic10             Topic11              Topic12  \
# Word1          (0.0282, model)     (0.0124, field)     (0.0485, theory)
# Word2   (0.0206, distribution)   (0.0114, surface)      (0.01, concept)
# Word3         (0.0174, method)   (0.009, magnetic)  (0.0097, structure)
# Word4        (0.0168, network)      (0.0073, beam)   (0.0094, physical)
# Word5      (0.0126, parameter)  (0.0065, velocity)  (0.0086, principle)
# Word6           (0.0122, data)      (0.0062, flow)    (0.0079, general)
# Word7          (0.0108, error)      (0.006, solar)     (0.0079, discus)
# Word8    (0.0105, probability)     (0.0059, layer)        (0.0078, new)
# Word9     (0.0096, estimation)      (0.0058, wave)       (0.007, force)
# Word10      (0.009, estimator)    (0.0055, plasma)    (0.0066, dynamic)
#
#                   Topic13                Topic14                 Topic15  \
# Word1     (0.0262, space)        (0.0227, model)      (0.0439, equation)
# Word2       (0.0126, set)       (0.0196, market)      (0.0302, solution)
# Word3   (0.0117, theorem)        (0.0154, price)        (0.0123, method)
# Word4     (0.0117, class)         (0.0146, risk)         (0.0116, model)
# Word5     (0.0115, prove)        (0.0116, agent)  (0.0109, differential)
# Word6    (0.0111, result)         (0.0111, game)     (0.0101, nonlinear)
# Word7     (0.0108, group)     (0.0096, strategy)     (0.0099, numerical)
# Word8      (0.0098, show)         (0.0081, show)      (0.0092, function)
# Word9       (0.0093, map)  (0.0078, equilibrium)       (0.009, operator)
# Word10    (0.0089, proof)    (0.0077, financial)       (0.009, category)
#
#                       Topic16                Topic17                 Topic18  \
# Word1         (0.0178, phase)       (0.0185, system)         (0.0165, model)
# Word2          (0.017, state)         (0.0124, user)          (0.0161, time)
# Word3         (0.0112, model)  (0.0106, application)          (0.0157, data)
# Word4    (0.0111, transition)       (0.0101, design)  (0.0085, distribution)
# Word5   (0.0099, temperature)        (0.0092, paper)          (0.0079, test)
# Word6         (0.0096, field)         (0.0081, data)          (0.0079, find)
# Word7   (0.0094, interaction)       (0.008, network)      (0.0072, analysis)
# Word8        (0.0085, effect)     (0.0072, software)   (0.0071, correlation)
# Word9        (0.0081, system)      (0.0063, service)        (0.0071, result)
# Word10     (0.0066, coupling)  (0.0062, performance)         (0.0068, scale)
#
#                      Topic19               Topic20
# Word1         (0.0226, cell)       (0.0337, power)
# Word2        (0.0222, model)      (0.0334, matrix)
# Word3      (0.0117, network)  (0.0212, polynomial)
# Word4         (0.0076, gene)     (0.0166, program)
# Word5      (0.0066, dynamic)      (0.0149, number)
# Word6      (0.0064, protein)   (0.0135, operation)
# Word7    (0.0061, mechanism)        (0.013, paper)
# Word8        (0.0061, study)      (0.011, circuit)
# Word9       (0.0058, growth)       (0.0107, ideal)
# Word10  (0.0057, biological)   (0.009, constraint)
#
# Document-Topic Table:
#                                                  Topic1  \
# Doc1  (0.8942, present analysis suzaku spectrum line...
# Doc2  (0.8874, diffuse interstellar cloud show large...
# Doc3  (0.8871, present midinfrared mir observation m...
# Doc4  (0.8809, iron emission line kev identified flu...
# Doc5  (0.8782, inclusive jet cross section event lar...
#
#                                                  Topic2  \
# Doc1  (0.8113, considering control problem nonlinear...
# Doc2  (0.752, paper new control scheme called additi...
# Doc3  (0.7451, deal system uncertainty finite automa...
# Doc4  (0.7012, paper propose novel cooperative trans...
# Doc5  (0.7012, paper propose novel cooperative trans...
#
#                                                  Topic3  \
# Doc1  (0.8886, bounded maxcoloring vertexedge weight...
# Doc2  (0.8694, let set point mathbbrd steiner convex...
# Doc3  (0.8626, given planar point set integer wish c...
# Doc4  (0.8309, total coloring graph coloring vertex ...
# Doc5  (0.8275, study problem computing geometric spa...
#
#                                                  Topic4  \
# Doc1  (0.9037, propose method zeroresource domain ad...
# Doc2  (0.9005, utterance contains speech multiple la...
# Doc3  (0.8988, work propose new approach language id...
# Doc4  (0.895, speaker recognition performance emotio...
# Doc5  (0.8947, investigate novel crosslingual multis...
#
#                                                  Topic5  \
# Doc1  (0.7857, novel algorithm proposed candecomppar...
# Doc2  (0.7842, consider system parallel queue task a...
# Doc3  (0.782, load balancing common approach web ser...
# Doc4  (0.7613, parallelizing set job across many ser...
# Doc5  (0.759, convex relaxation optimal finger selec...
#
#                                                  Topic6  \
# Doc1  (0.9197, leo goodman born august new york city...
# Doc2  (0.9021, george roussas born city marmara cent...
# Doc3  (0.8925, harry martz born june grew cumberland...
# Doc4  (0.8821, born sydney australia april chris hey...
# Doc5  (0.8807, public law congress established offic...
#
#                                                  Topic7  \
# Doc1  (0.8266, depth image provides partial geometri...
# Doc2  (0.8247, paper present novel pseudo sequence b...
# Doc3  (0.8017, new technique data hiding digital ima...
# Doc4  (0.7948, freeviewpoint video conferencing allo...
# Doc5  (0.7942, propose new approach image compressio...
#
#                                                  Topic8  \
# Doc1  (0.8752, algebra homomorphism psi nonstandard ...
# Doc2  (0.8676, associative ring said semilocal provi...
# Doc3  (0.8528, starting given smatrix integrable qua...
# Doc4  (0.8351, algebra homomorphism psi qdeformed al...
# Doc5  (0.8269, classify dimensional first order bico...
#
#                                                  Topic9  \
# Doc1  (0.8776, myosin myosin two class twoheaded mol...
# Doc2  (0.7934, partitioning transport water small so...
# Doc3  (0.7831, fission metastable charged univalent ...
# Doc4  (0.7635, recent experiment amyloidbeta abeta p...
# Doc5  (0.7456, molecular dynamic simulation free ene...
#
#                                                 Topic10  \
# Doc1  (0.8895, consider class semiparametric regress...
# Doc2  (0.8895, consider class semiparametric regress...
# Doc3  (0.879, paper considers panel data model condi...
# Doc4  (0.874, approximate bayesian computation abc m...
# Doc5  (0.8648, generalized likelihood ratio statisti...
#
#                                                 Topic11  \
# Doc1  (0.8829, champ magnetic field variation intern...
# Doc2  (0.8685, paper investigates relative scintilla...
# Doc3  (0.8646, performed analysis case event statist...
# Doc4  (0.8624, convection inside magnetosphere regar...
# Doc5  (0.8572, model subduction buoyant ridge platea...
#
#                                                 Topic12  \
# Doc1  (0.8246, work einstein view geometry physical ...
# Doc2  (0.789, einstein distinguished principle const...
# Doc3  (0.7823, shown paper difference two form relat...
# Doc4  (0.7719, shown comparison prerelativistic gali...
# Doc5  (0.7499, wellknown experiment muon experiment ...
#
#                                                 Topic13  \
# Doc1  (0.9225, prove algebraic hypersurfaces defined...
# Doc2  (0.903, let projective irreducible smooth alge...
# Doc3  (0.9002, paper prove result existence homotopy...
# Doc4  (0.8932, given connected open manifold finitel...
# Doc5  (0.8888, hausdorff topological group gtau call...
#
#                                                 Topic14  \
# Doc1  (0.875, propose model credit market random def...
# Doc2  (0.8727, develop finite horizon continuous tim...
# Doc3  (0.8618, study robust double auction mechanism...
# Doc4  (0.8514, propose model jointly calibrated corp...
# Doc5  (0.8371, optimal strategy longterm static inve...
#
#                                                 Topic15  \
# Doc1  (0.8286, advection equation basis mathematical...
# Doc2  (0.8041, study class quadratically nonlinear w...
# Doc3  (0.7945, spectral problem vzpsizpsi considered...
# Doc4  (0.7922, initial value problem kortewegde vrie...
# Doc5  (0.7905, present special solution discrete pai...
#
#                                                 Topic16  \
# Doc1  (0.8786, formation magnetically ordered state ...
# Doc2  (0.877, study effect disorder system two coupl...
# Doc3  (0.8623, investigate transport interacting ele...
# Doc4  (0.8602, study planar ferromagnetic spinchain ...
# Doc5  (0.854, present detail earlier study zheng phy...
#
#                                                 Topic17  \
# Doc1  (0.8767, agent technology new paradigm softwar...
# Doc2  (0.8744, legacy adadas development oems center...
# Doc3  (0.8738, application development distributed c...
# Doc4  (0.8689, virtualization generally adopted serv...
# Doc5  (0.8595, datagrid project workpackage objectiv...
#
#                                                 Topic18  \
# Doc1  (0.8509, using deep infrared observation condu...
# Doc2  (0.8365, abridged formation massive spheroidal...
# Doc3  (0.8289, investigate effect gaspoor socalled d...
# Doc4  (0.8265, following study darg hereafter explor...
# Doc5  (0.8184, abridge bar common centre disc galaxy...
#
#                                                 Topic19  \
# Doc1  (0.8973, development tumor known result accumu...
# Doc2  (0.8932, background epidermal growth factor re...
# Doc3  (0.8881, pebps phosphatidylethanolamine bindin...
# Doc4  (0.8762, activation naive tcells lead generati...
# Doc5  (0.8754, leishmania lipophosphoglycan molecule...
#
#                                                 Topic20
# Doc1  (0.8144, ieee ongoing revision ieee floating p...
# Doc2  (0.7905, recent year reversible logic emerged ...
# Doc3  (0.7891, ieee ongoing revision ieee floating p...
# Doc4  (0.7799, recent year reversible logic emerged ...
# Doc5  (0.7654, large amount research currently going...
#
# Training LDA with 25 topics, alpha=0.5, beta=0.1...
# Perplexity for LDA with 25 topics: 2378.6976
#
# Word-Topic Table:
#                        Topic1               Topic2              Topic3  \
# Word1      (0.0162, spectrum)     (0.0691, system)   (0.0334, problem)
# Word2           (0.015, star)     (0.033, control)     (0.0302, graph)
# Word3        (0.0115, source)      (0.0195, bound)    (0.0255, number)
# Word4        (0.0111, galaxy)      (0.0161, state)      (0.0144, tree)
# Word5      (0.0107, emission)     (0.0143, energy)     (0.0139, bound)
# Word6          (0.0104, line)   (0.0142, proposed)  (0.0138, sequence)
# Word7          (0.0082, mass)       (0.0133, time)    (0.0137, random)
# Word8           (0.008, xray)   (0.0128, protocol)  (0.0118, distance)
# Word9   (0.0077, observation)  (0.0109, stability)   (0.0112, lattice)
# Word10       (0.0073, energy)      (0.0105, paper)    (0.0109, length)
#
#                     Topic4                  Topic5                  Topic6  \
# Word1     (0.0474, method)     (0.0638, algorithm)         (0.0853, field)
# Word2      (0.0142, model)       (0.0224, problem)       (0.026, magnetic)
# Word3   (0.0137, proposed)          (0.0161, time)        (0.0183, motion)
# Word4    (0.0137, feature)  (0.0107, optimization)         (0.0166, force)
# Word5   (0.0125, approach)   (0.0099, performance)        (0.0165, effect)
# Word6      (0.0125, based)        (0.0095, memory)     (0.0109, direction)
# Word7   (0.0125, learning)          (0.0092, show)      (0.0087, electric)
# Word8      (0.0122, using)      (0.0088, approach)  (0.0075, polarization)
# Word9     (0.0104, signal)       (0.0079, propose)      (0.0071, material)
# Word10    (0.0096, result)        (0.0077, result)        (0.0058, system)
#
#                           Topic7                   Topic8  \
# Word1             (0.036, image)        (0.0367, channel)
# Word2             (0.0244, code)         (0.0363, system)
# Word3             (0.0238, data)    (0.0272, information)
# Word4          (0.0106, quality)         (0.0225, scheme)
# Word5        (0.0102, algorithm)  (0.0174, communication)
# Word6        (0.0097, technique)       (0.0146, capacity)
# Word7            (0.0094, video)           (0.0141, rate)
# Word8   (0.0079, reconstruction)         (0.0133, signal)
# Word9            (0.0078, using)   (0.0105, transmission)
# Word10           (0.0069, paper)        (0.0095, quantum)
#
#                       Topic9                Topic10  ...  \
# Word1      (0.0195, cluster)        (0.0296, model)  ...
# Word2    (0.0166, structure)       (0.0206, method)  ...
# Word3      (0.0157, protein)  (0.018, distribution)  ...
# Word4       (0.0123, energy)    (0.0138, parameter)  ...
# Word5     (0.0115, molecule)         (0.0133, data)  ...
# Word6    (0.0112, molecular)      (0.0127, network)  ...
# Word7    (0.0109, mechanism)   (0.0109, estimation)  ...
# Word8        (0.0095, model)      (0.01, estimator)  ...
# Word9   (0.0093, functional)        (0.0098, error)  ...
# Word10       (0.008, result)     (0.0096, estimate)  ...
#
#                       Topic16                Topic17                 Topic18  \
# Word1         (0.0259, state)       (0.0258, system)          (0.0194, time)
# Word2         (0.0225, phase)       (0.0154, design)          (0.0182, data)
# Word3    (0.0144, transition)  (0.0148, application)         (0.0167, model)
# Word4         (0.0123, model)  (0.0099, performance)          (0.0118, test)
# Word5   (0.0102, interaction)     (0.0098, software)  (0.0099, distribution)
# Word6        (0.0101, system)        (0.0091, paper)      (0.0096, analysis)
# Word7   (0.0097, temperature)        (0.0085, model)        (0.0083, change)
# Word8          (0.0081, mode)        (0.008, device)         (0.0079, study)
# Word9     (0.0079, frequency)   (0.0078, simulation)        (0.0079, period)
# Word10      (0.0068, density)         (0.0075, used)        (0.0075, result)
#
#                      Topic19                Topic20                Topic21  \
# Word1         (0.0253, cell)       (0.0476, matrix)       (0.0233, energy)
# Word2        (0.0238, model)        (0.0297, power)         (0.0186, mass)
# Word3      (0.0158, network)   (0.0179, constraint)     (0.0122, particle)
# Word4         (0.0085, gene)       (0.016, program)       (0.0109, result)
# Word5      (0.0072, dynamic)   (0.0147, polynomial)        (0.0106, decay)
# Word6   (0.0062, biological)    (0.0139, operation)      (0.0101, section)
# Word7       (0.0061, growth)       (0.013, circuit)          (0.01, model)
# Word8        (0.0059, study)        (0.0116, paper)  (0.0095, calculation)
# Word9     (0.0059, response)  (0.0114, computation)  (0.0085, measurement)
# Word10     (0.0059, process)          (0.0093, new)       (0.0083, matter)
#
#                      Topic22                Topic23                   Topic24  \
# Word1     (0.0429, equation)     (0.0112, research)           (0.0409, group)
# Word2     (0.0285, solution)        (0.0096, paper)         (0.0237, algebra)
# Word3       (0.0146, method)         (0.0096, user)          (0.0111, finite)
# Word4     (0.0134, function)  (0.0095, information)  (0.0103, representation)
# Word5      (0.0124, problem)          (0.009, data)            (0.0101, ring)
# Word6      (0.0117, quantum)      (0.0062, science)         (0.0099, product)
# Word7     (0.0116, operator)       (0.0062, social)            (0.0096, show)
# Word8     (0.011, numerical)       (0.006, network)             (0.0089, lie)
# Word9   (0.01, differential)          (0.0054, web)             (0.0084, let)
# Word10         (0.01, model)           (0.005, new)          (0.0082, result)
#
#                     Topic25
# Word1       (0.0245, model)
# Word2      (0.0205, market)
# Word3       (0.0162, price)
# Word4        (0.0157, risk)
# Word5       (0.0125, agent)
# Word6    (0.0115, strategy)
# Word7     (0.0096, optimal)
# Word8     (0.0092, process)
# Word9   (0.0081, financial)
# Word10     (0.0081, option)
#
# [10 rows x 25 columns]
#
# Document-Topic Table:
#                                                  Topic1  \
# Doc1  (0.8902, present high resolution measurement n...
# Doc2  (0.8901, present analysis suzaku spectrum line...
# Doc3  (0.8868, discus xray property radio source det...
# Doc4  (0.8796, present midinfrared mir observation m...
# Doc5  (0.8755, present first spitzer infrared spectr...
#
#                                                  Topic2  \
# Doc1  (0.7626, considering control problem nonlinear...
# Doc2  (0.7214, paper new control scheme called addit...
# Doc3  (0.6883, chienjantseng introduced efficient re...
# Doc4  (0.6799, chen proposed efficient remote user a...
# Doc5  (0.6794, paper considers leaderfollower contro...
#
#                                                  Topic3  \
# Doc1  (0.8621, bounded maxcoloring vertexedge weight...
# Doc2  (0.8535, let set point mathbbrd steiner convex...
# Doc3  (0.8196, finding largest clique notoriously ha...
# Doc4  (0.8162, given planar point set integer wish c...
# Doc5  (0.7986, kvc problem given undirected graph ed...
#
#                                                  Topic4  \
# Doc1  (0.8744, speaker recognition performance emoti...
# Doc2  (0.8669, work propose new approach language id...
# Doc3  (0.8663, well known speaker identification yie...
# Doc4  (0.8627, utterance contains speech multiple la...
# Doc5  (0.8559, work research devoted studying enhanc...
#
#                                                  Topic5  \
# Doc1  (0.7786, data intensive application often invo...
# Doc2  (0.7734, efficiently exploiting resource data ...
# Doc3  (0.7525, load balancing system comprising cent...
# Doc4  (0.7508, mapreduce framework facto big data ap...
# Doc5  (0.7505, queue required service provider able ...
#
#                                                  Topic6  \
# Doc1  (0.7171, known repulsion volume element unifor...
# Doc2  (0.6903, liion battery ineluctably subjected e...
# Doc3  (0.6667, turbulent diffusion tensor describing...
# Doc4  (0.6378, appearance time derivative accelerati...
# Doc5  (0.6267, magnetooptically active thin film rbj...
#
#                                                  Topic7  \
# Doc1  (0.8411, propose new approach image compressio...
# Doc2  (0.8183, depth image provides partial geometri...
# Doc3  (0.7908, new technique data hiding digital ima...
# Doc4  (0.7806, multispectral imaging utilized many f...
# Doc5  (0.7778, paper present novel pseudo sequence b...
#
#                                                  Topic8  \
# Doc1  (0.8589, one feature characterizing almost eve...
# Doc2  (0.8589, one feature characterizing almost eve...
# Doc3  (0.8408, paper performance binary phase shift ...
# Doc4  (0.8408, paper performance binary phase shift ...
# Doc5  (0.8358, multiple transmit antenna downlink ch...
#
#                                                  Topic9  \
# Doc1  (0.8256, partitioning transport water small so...
# Doc2  (0.8012, fission metastable charged univalent ...
# Doc3  (0.7903, recent experiment amyloidbeta abeta p...
# Doc4  (0.783, use initio static relaxation method se...
# Doc5  (0.7551, investigated lowestenergy structure e...
#
#                                                 Topic10  ...  \
# Doc1  (0.8318, paper considers panel data model cond...  ...
# Doc2  (0.8286, generalized likelihood ratio statisti...  ...
# Doc3  (0.8286, generalized likelihood ratio statisti...  ...
# Doc4  (0.8286, consistency even oracle property esti...  ...
# Doc5  (0.8281, consider inference procedure conditio...  ...
#
#                                                 Topic16  \
# Doc1  (0.8196, investigate transport interacting ele...
# Doc2  (0.8109, study effect disorder system two coup...
# Doc3  (0.791, study quasitwodimensional bose gas har...
# Doc4  (0.7851, consider quantized vortex twocomponen...
# Doc5  (0.7785, study exact dynamic onedimensional sp...
#
#                                                 Topic17  \
# Doc1  (0.7858, recently fpga accelerator risen popul...
# Doc2  (0.7768, almost modern hardware phone socs hig...
# Doc3  (0.7721, paper outline design questv implement...
# Doc4  (0.7712, application specific simulation chall...
# Doc5  (0.7706, data acquisition system accelerator c...
#
#                                                 Topic18  \
# Doc1  (0.778, growth rate real gdp per caput biggest...
# Doc2  (0.7764, show analytically answer question lon...
# Doc3  (0.7756, investigate climate model contributin...
# Doc4  (0.768, climate sensitivity defined change glo...
# Doc5  (0.7571, warming trend last decade strong disc...
#
#                                                 Topic19  \
# Doc1  (0.8686, development tumor known result accumu...
# Doc2  (0.8493, skin one largest human organ system w...
# Doc3  (0.849, background epidermal growth factor rec...
# Doc4  (0.845, experimental evidence indicates human ...
# Doc5  (0.8442, primary tumor infrequently lead demis...
#
#                                                 Topic20  \
# Doc1  (0.8279, ieee ongoing revision ieee floating p...
# Doc2  (0.794, recent year reversible logic emerged p...
# Doc3  (0.7913, recent year reversible logic emerged ...
# Doc4  (0.7853, reversible computing attracted attent...
# Doc5  (0.776, ieee ongoing revision ieee floating po...
#
#                                                 Topic21  \
# Doc1  (0.869, production phi meson reaction rightarr...
# Doc2  (0.8549, inclusive jet cross section event lar...
# Doc3  (0.8307, search leptoquarks hera performed usi...
# Doc4  (0.8299, exclusive production rho meson deep i...
# Doc5  (0.8231, measurement inclusive charged particl...
#
#                                                 Topic22  \
# Doc1  (0.7682, recursion operator symmetry nonautono...
# Doc2  (0.7648, advection equation basis mathematical...
# Doc3  (0.7536, technique darboux transformation appl...
# Doc4  (0.7448, discrete laplace transform inversion ...
# Doc5  (0.734, simple general approach calculating el...
#
#                                                 Topic23  \
# Doc1  (0.8669, increasing participation people onlin...
# Doc2  (0.8615, university expanding data science pro...
# Doc3  (0.852, harry martz born june grew cumberland ...
# Doc4  (0.8506, advance web service technology emerge...
# Doc5  (0.8421, early election call fall provided per...
#
#                                                 Topic24  \
# Doc1  (0.8599, paper classify triangular semisimple ...
# Doc2  (0.8453, azumaya algebra free centre prove kth...
# Doc3  (0.8396, define tracial rokhlin property actio...
# Doc4  (0.8352, given action monoid ring ring endomor...
# Doc5  (0.8338, let gamma countable abelian semigroup...
#
#                                                 Topic25
# Doc1  (0.8509, introduce twoagent problem inspired p...
# Doc2  (0.8326, develop finite horizon continuous tim...
# Doc3  (0.828, propose model jointly calibrated corpo...
# Doc4  (0.8225, paper investigate hedging problem uni...
# Doc5  (0.8108, consider market player tailriskseekin...
#
# [5 rows x 25 columns]
#
# Training LDA with 30 topics, alpha=0.5, beta=0.1...
# Perplexity for LDA with 30 topics: 2439.7467
#
# Word-Topic Table:
#                        Topic1              Topic2              Topic3  \
# Word1        (0.0644, energy)     (0.054, system)     (0.0448, graph)
# Word2         (0.0441, model)     (0.0448, bound)  (0.0332, sequence)
# Word3      (0.0329, spectrum)   (0.0323, control)    (0.0233, number)
# Word4         (0.0089, range)     (0.0187, state)      (0.0214, tree)
# Word5       (0.0085, nuclear)     (0.0167, lower)   (0.0211, lattice)
# Word6        (0.0077, effect)  (0.0154, protocol)    (0.0192, length)
# Word7        (0.0073, result)  (0.0142, proposed)  (0.0189, distance)
# Word8   (0.0072, calculation)     (0.0141, upper)      (0.0148, edge)
# Word9        (0.0072, source)      (0.0126, time)    (0.0139, vertex)
# Word10      (0.0068, nucleus)     (0.0108, paper)      (0.0135, path)
#
#                     Topic4                 Topic5                 Topic6  \
# Word1      (0.051, method)    (0.0188, algorithm)        (0.0657, field)
# Word2   (0.0149, proposed)          (0.018, time)       (0.0263, motion)
# Word3    (0.0143, feature)       (0.0145, memory)        (0.0192, force)
# Word4      (0.0131, based)  (0.0141, performance)        (0.018, effect)
# Word5    (0.013, approach)         (0.0115, data)       (0.0174, system)
# Word6      (0.0127, model)         (0.0112, node)      (0.0166, dynamic)
# Word7      (0.0124, using)         (0.0107, task)     (0.014, direction)
# Word8   (0.0122, learning)      (0.0097, propose)  (0.0088, fluctuation)
# Word9     (0.0104, signal)     (0.0092, approach)     (0.0085, external)
# Word10    (0.0097, result)         (0.0087, show)   (0.007, orientation)
#
#                           Topic7                   Topic8  \
# Word1            (0.0384, image)         (0.0425, system)
# Word2             (0.0266, code)        (0.0392, channel)
# Word3             (0.0244, data)    (0.0285, information)
# Word4         (0.012, algorithm)          (0.028, scheme)
# Word5          (0.0117, quality)  (0.0197, communication)
# Word6            (0.0102, video)       (0.0154, capacity)
# Word7          (0.01, technique)         (0.0148, signal)
# Word8   (0.0082, reconstruction)           (0.0142, rate)
# Word9            (0.0077, using)   (0.0112, transmission)
# Word10        (0.0075, database)       (0.0085, receiver)
#
#                       Topic9               Topic10  ...              Topic21  \
# Word1      (0.0205, protein)       (0.0297, model)  ...       (0.0241, mass)
# Word2      (0.0203, cluster)     (0.0267, network)  ...    (0.0135, section)
# Word3   (0.0195, functional)      (0.0241, method)  ...     (0.0122, result)
# Word4    (0.0142, structure)   (0.0146, parameter)  ...   (0.0112, coupling)
# Word5    (0.0128, molecular)        (0.0143, data)  ...      (0.0111, decay)
# Word6        (0.0125, logic)  (0.0134, estimation)  ...   (0.0098, function)
# Word7      (0.012, molecule)       (0.0129, error)  ...   (0.0098, momentum)
# Word8        (0.0116, model)   (0.0121, estimator)  ...  (0.0095, collision)
# Word9   (0.0089, structural)    (0.0117, estimate)  ...      (0.0094, value)
# Word10    (0.0085, reaction)    (0.0094, approach)  ...      (0.0093, cross)
#
#                        Topic22              Topic23                   Topic24  \
# Word1       (0.0507, equation)   (0.0121, research)           (0.0543, group)
# Word2       (0.0313, solution)       (0.0101, user)         (0.0306, algebra)
# Word3          (0.018, method)  (0.01, information)  (0.0155, representation)
# Word4      (0.0134, numerical)      (0.0096, paper)            (0.0127, ring)
# Word5         (0.0124, system)        (0.008, data)         (0.0117, product)
# Word6   (0.0119, differential)     (0.0067, social)          (0.0113, finite)
# Word7       (0.0105, function)    (0.0067, science)              (0.011, lie)
# Word8             (0.01, term)        (0.0058, web)           (0.0098, ideal)
# Word9       (0.0096, operator)    (0.0054, student)            (0.0096, show)
# Word10         (0.0092, model)    (0.0053, network)          (0.0085, module)
#
#                      Topic25                Topic26             Topic27  \
# Word1         (0.027, model)        (0.03, quantum)       (0.0211, set)
# Word2       (0.0243, market)        (0.0245, state)     (0.0188, space)
# Word3        (0.0191, price)        (0.0239, phase)   (0.0176, theorem)
# Word4         (0.0186, risk)  (0.0166, temperature)  (0.0153, function)
# Word5     (0.0102, strategy)   (0.0164, transition)     (0.0144, proof)
# Word6    (0.0096, financial)         (0.0125, spin)     (0.0143, prove)
# Word7       (0.0095, option)         (0.0086, atom)  (0.0128, manifold)
# Word8   (0.0087, volatility)      (0.0085, density)    (0.0121, result)
# Word9      (0.0086, process)   (0.008, interaction)  (0.0112, operator)
# Word10   (0.0084, portfolio)    (0.0075, structure)     (0.0092, paper)
#
#                    Topic28                Topic29                  Topic30
# Word1   (0.0291, particle)         (0.0147, star)        (0.0886, problem)
# Word2      (0.0279, field)  (0.0107, observation)      (0.0625, algorithm)
# Word3   (0.0257, magnetic)       (0.0107, galaxy)        (0.0183, optimal)
# Word4        (0.021, beam)         (0.0088, mass)   (0.0111, optimization)
# Word5   (0.0182, electron)         (0.0077, disk)           (0.0111, case)
# Word6    (0.0174, current)     (0.0073, emission)  (0.0105, approximation)
# Word7     (0.0141, plasma)          (0.007, line)           (0.0102, time)
# Word8     (0.0118, charge)        (0.0068, solar)       (0.0099, solution)
# Word9        (0.0117, ion)       (0.0067, planet)           (0.0099, show)
# Word10      (0.0106, wave)       (0.0062, source)          (0.009, result)
#
# [10 rows x 30 columns]
#
# Document-Topic Table:
#                                                  Topic1  \
# Doc1  (0.7348, paper examines cosmic ray nucleus spe...
# Doc2  (0.7138, developed model proton depth dose lat...
# Doc3  (0.7138, developed model proton depth dose lat...
# Doc4  (0.7062, utilizing new voyager measurement low...
# Doc5  (0.6601, deap lowbackground liquid argon detec...
#
#                                                  Topic2  \
# Doc1  (0.6834, considering control problem nonlinear...
# Doc2  (0.6436, protected password change protocol pr...
# Doc3  (0.6372, paper new control scheme called addit...
# Doc4  (0.6297, byzantine agreement algorithm typical...
# Doc5  (0.6271, passwordbased authentication scheme w...
#
#                                                  Topic3  \
# Doc1  (0.7541, total coloring graph coloring vertex ...
# Doc2  (0.7004, method obtain possible graceful spann...
# Doc3  (0.686, acyclic edge coloring graph proper edg...
# Doc4  (0.6492, article temperleys bijection spanning...
# Doc5  (0.6483, given set positive integer associated...
#
#                                                  Topic4  \
# Doc1  (0.8523, speaker recognition performance emoti...
# Doc2  (0.8317, work aimed exploiting secondorder cir...
# Doc3  (0.8253, work research devoted studying enhanc...
# Doc4  (0.8238, automatic speech recognition asr mult...
# Doc5  (0.8197, usually people talk neutrally environ...
#
#                                                  Topic5  \
# Doc1  (0.8213, data intensive application often invo...
# Doc2  (0.7644, data warehouse data mart system query...
# Doc3  (0.7527, dataintensive application often requi...
# Doc4  (0.7412, efficiently exploiting resource data ...
# Doc5  (0.738, queue required service provider able h...
#
#                                                  Topic6  \
# Doc1  (0.641, purpose present experiment investigate...
# Doc2  (0.5822, separate study reported postural cont...
# Doc3  (0.5795, investigated effect plantar pressureb...
# Doc4  (0.5511, present study aimed investigating eff...
# Doc5  (0.5191, present study focused effect trunk ex...
#
#                                                  Topic7  \
# Doc1  (0.764, propose new approach image compression...
# Doc2  (0.755, depth image provides partial geometric...
# Doc3  (0.752, new technique data hiding digital imag...
# Doc4  (0.7259, visual display unit vdu capable displ...
# Doc5  (0.7183, multispectral imaging utilized many f...
#
#                                                  Topic8  \
# Doc1  (0.8335, one feature characterizing almost eve...
# Doc2  (0.8335, one feature characterizing almost eve...
# Doc3  (0.8167, paper introduce novel use linear spat...
# Doc4  (0.8167, paper introduce novel use linear spat...
# Doc5  (0.8007, multiple transmit antenna downlink ch...
#
#                                                  Topic9  \
# Doc1  (0.6925, phivalues experimental measure effect...
# Doc2  (0.6828, amyloid fiber aggregate protein built...
# Doc3  (0.6693, binding ligand molecule protein often...
# Doc4  (0.666, cellular cargo bound cytoskeletal fila...
# Doc5  (0.6601, observed topology native state import...
#
#                                                 Topic10  ...  \
# Doc1  (0.7952, consistency even oracle property esti...  ...
# Doc2  (0.7919, approximate bayesian computation abc ...  ...
# Doc3  (0.7898, paper develops empirical balancing ap...  ...
# Doc4  (0.7877, paper considers panel data model cond...  ...
# Doc5  (0.7822, study identification nonparametric re...  ...
#
#                                                 Topic21  \
# Doc1  (0.8395, production phi meson reaction rightar...
# Doc2  (0.763, electronproton collider hera inclusive...
# Doc3  (0.7598, search leptoquarks hera performed usi...
# Doc4  (0.7572, nous etudions dans cette fonctionnell...
# Doc5  (0.7572, nous etudions dans cette fonctionnell...
#
#                                                 Topic22  \
# Doc1  (0.7258, recursion operator symmetry nonautono...
# Doc2  (0.7123, technique darboux transformation appl...
# Doc3  (0.703, similarity reduction new exact solutio...
# Doc4  (0.6985, advection equation basis mathematical...
# Doc5  (0.6974, simple general approach calculating e...
#
#                                                 Topic23  \
# Doc1  (0.8403, university expanding data science pro...
# Doc2  (0.8352, increasing participation people onlin...
# Doc3  (0.8263, harry martz born june grew cumberland...
# Doc4  (0.822, present two program address need bette...
# Doc5  (0.8188, advance web service technology emerge...
#
#                                                 Topic24  \
# Doc1  (0.8341, azumaya algebra free centre prove kth...
# Doc2  (0.7956, sacerdote shown nonabelian free group...
# Doc3  (0.7869, finite group semimackey functors semi...
# Doc4  (0.786, every profinite group construct two co...
# Doc5  (0.7812, group said csagroup maximal abelian s...
#
#                                                 Topic25  \
# Doc1  (0.8095, propose model jointly calibrated corp...
# Doc2  (0.8052, develop finite horizon continuous tim...
# Doc3  (0.7956, study hedging pricing unattainable co...
# Doc4  (0.7853, paper investigate hedging problem uni...
# Doc5  (0.7819, paper study stochastic modeling marke...
#
#                                                 Topic26  \
# Doc1  (0.7834, electronic property graphene decorate...
# Doc2  (0.7609, selfconsistent treatment exchange cor...
# Doc3  (0.7561, use spectral density approach influen...
# Doc4  (0.7488, paper present study exciton system el...
# Doc5  (0.7484, lowenergy property onedimensional kon...
#
#                                                 Topic27  \
# Doc1  (0.8862, prove algebraic hypersurfaces defined...
# Doc2  (0.8268, paper prove result existence homotopy...
# Doc3  (0.8016, given connected open manifold finitel...
# Doc4  (0.7987, sequence real number define inner pro...
# Doc5  (0.797, famous paper lempert proved given poin...
#
#                                                 Topic28  \
# Doc1  (0.7453, understanding scrapeoff layer sol phy...
# Doc2  (0.7384, plasma production whistler wave range...
# Doc3  (0.7178, parameter gev test beam outlined use ...
# Doc4  (0.7156, new experimental result multimirror t...
# Doc5  (0.7039, report measurement charge transfer ge...
#
#                                                 Topic29  \
# Doc1  (0.8693, present midinfrared mir observation m...
# Doc2  (0.8663, using speckle camera sharp eso ntt ko...
# Doc3  (0.8662, discus xray property radio source det...
# Doc4  (0.8617, abridged present multiepoch highresol...
# Doc5  (0.8604, present high resolution measurement n...
#
#                                                 Topic30
# Doc1  (0.8194, recent work addressed algorithmic pro...
# Doc2  (0.8067, budget feasible mechanism recently in...
# Doc3  (0.7989, given set agent set item agent utilit...
# Doc4  (0.7764, consider problem designing revenuemax...
# Doc5  (0.7742, sponsored search auction advertisemen...
#
# [5 rows x 30 columns]
#
# Best LDA Model:
# Number of Topics: 15
# Perplexity: 2324.4677
#
# Word-Topic Table for Best Model:
#                     Topic1              Topic2              Topic3  \
# Word1     (0.0153, energy)    (0.0667, system)     (0.0179, graph)
# Word2       (0.0118, mass)   (0.0258, control)  (0.0168, function)
# Word3      (0.0098, model)     (0.0221, power)    (0.0136, number)
# Word4   (0.0092, spectrum)     (0.017, design)     (0.0132, bound)
# Word5       (0.0082, star)     (0.0102, paper)   (0.0115, lattice)
# Word6     (0.0061, galaxy)  (0.0097, proposed)      (0.011, model)
# Word7   (0.0057, emission)     (0.009, energy)    (0.0109, result)
# Word8    (0.0056, cluster)     (0.0083, state)      (0.0081, show)
# Word9     (0.0055, result)   (0.0073, circuit)    (0.0081, random)
# Word10      (0.0055, data)     (0.0071, based)      (0.0078, tree)
#
#                     Topic4                  Topic5                 Topic6  \
# Word1     (0.0298, method)     (0.0487, algorithm)     (0.0109, research)
# Word2      (0.0139, model)       (0.0335, problem)        (0.0094, paper)
# Word3      (0.0118, image)          (0.0139, time)         (0.0063, year)
# Word4       (0.011, based)        (0.0121, method)      (0.0063, science)
# Word5       (0.011, using)         (0.011, matrix)  (0.0063, development)
# Word6   (0.0107, proposed)       (0.0099, optimal)         (0.006, study)
# Word7   (0.0106, approach)   (0.0093, performance)          (0.0057, new)
# Word8     (0.0102, result)  (0.0091, optimization)       (0.0053, social)
# Word9     (0.01, learning)      (0.0086, approach)       (0.0051, physic)
# Word10   (0.0093, feature)          (0.0079, show)      (0.0049, student)
#
#                        Topic7                 Topic8                 Topic9  \
# Word1          (0.0179, data)      (0.0387, quantum)         (0.0212, cell)
# Word2          (0.0122, user)       (0.0318, system)        (0.0177, model)
# Word3   (0.0112, application)        (0.0297, state)      (0.0108, protein)
# Word4          (0.0093, code)      (0.0251, channel)         (0.0069, gene)
# Word5   (0.0086, information)        (0.0097, field)      (0.0067, process)
# Word6         (0.0086, paper)     (0.0097, particle)     (0.006, mechanism)
# Word7        (0.0083, system)     (0.009, classical)      (0.0059, dynamic)
# Word8      (0.0071, software)     (0.0084, capacity)    (0.0054, molecular)
# Word9          (0.0062, tool)  (0.0084, information)  (0.0053, interaction)
# Word10       (0.006, network)          (0.0083, two)     (0.0053, molecule)
#
#                        Topic10                Topic11              Topic12  \
# Word1          (0.0314, model)        (0.0121, field)     (0.0192, theory)
# Word2   (0.0194, distribution)     (0.0098, magnetic)    (0.0182, network)
# Word3           (0.0168, data)        (0.0083, phase)    (0.0137, dynamic)
# Word4         (0.0154, method)      (0.0083, surface)      (0.0105, agent)
# Word5        (0.0137, network)  (0.0072, temperature)   (0.0084, behavior)
# Word6      (0.0121, parameter)        (0.007, effect)       (0.008, model)
# Word7          (0.0083, error)    (0.0066, frequency)  (0.0073, structure)
# Word8       (0.0082, estimate)     (0.0061, electron)    (0.0068, pattern)
# Word9     (0.0078, estimation)          (0.006, wave)   (0.0064, analysis)
# Word10   (0.0077, probability)          (0.006, mode)      (0.0063, study)
#
#                   Topic13              Topic14                 Topic15
# Word1     (0.0184, space)      (0.0184, model)      (0.0343, equation)
# Word2     (0.0176, group)      (0.016, market)       (0.022, solution)
# Word3        (0.011, set)      (0.0126, price)         (0.0126, model)
# Word4   (0.0109, algebra)       (0.0116, risk)     (0.0107, nonlinear)
# Word5    (0.0096, result)       (0.0091, game)        (0.0098, method)
# Word6     (0.0094, class)   (0.0089, strategy)        (0.0094, theory)
# Word7     (0.0088, prove)        (0.008, show)     (0.0086, numerical)
# Word8      (0.0087, show)       (0.0069, time)  (0.0082, differential)
# Word9     (0.0086, paper)    (0.0064, process)          (0.008, field)
# Word10  (0.0083, theorem)  (0.0063, financial)          (0.0072, case)
#
# Document-Topic Table for Best Model:
#                                                  Topic1  \
# Doc1  (0.9421, discus xray property radio source det...
# Doc2  (0.9392, model disk galaxy formation commonly ...
# Doc3  (0.9391, present high resolution measurement n...
# Doc4  (0.9384, black hole binary transient undergo d...
# Doc5  (0.9383, compare spectral property short long ...
#
#                                                  Topic2  \
# Doc1  (0.889, paper low power low area array multipl...
# Doc2  (0.8704, onchip voltage regulation using distr...
# Doc3  (0.8684, paper proposes lowpower energy effici...
# Doc4  (0.8553, ieee ongoing revision ieee floating p...
# Doc5  (0.8448, considering control problem nonlinear...
#
#                                                  Topic3  \
# Doc1  (0.8657, total coloring graph coloring vertex ...
# Doc2  (0.8605, study dynamical property random trans...
# Doc3  (0.8461, study numerically paramagnetic phase ...
# Doc4  (0.8399, investigate localization two interact...
# Doc5  (0.832, new graphical method developed calcula...
#
#                                                  Topic4  \
# Doc1  (0.9278, utterance contains speech multiple la...
# Doc2  (0.9263, propose method zeroresource domain ad...
# Doc3  (0.9253, work propose new approach language id...
# Doc4  (0.9236, investigate novel crosslingual multis...
# Doc5  (0.9213, speaker recognition performance emoti...
#
#                                                  Topic5  \
# Doc1  (0.8684, paper present analyze new set lowrank...
# Doc2  (0.8625, novel algorithm proposed candecomppar...
# Doc3  (0.8493, matrix tensor completion aim recover ...
# Doc4  (0.8474, recent study sparse modeling nonconve...
# Doc5  (0.8405, attractiveness canonical polyadic ten...
#
#                                                  Topic6  \
# Doc1  (0.9405, leo goodman born august new york city...
# Doc2  (0.9194, george roussas born city marmara cent...
# Doc3  (0.9179, tadeusz calinski born poznan poland d...
# Doc4  (0.909, present two program address need bette...
# Doc5  (0.9053, harry martz born june grew cumberland...
#
#                                                  Topic7  \
# Doc1  (0.9185, grid based system require database ac...
# Doc2  (0.9126, pool project common persistency frame...
# Doc3  (0.9097, paper introduces writeoncereadmany xm...
# Doc4  (0.8978, information retrieval distributed het...
# Doc5  (0.897, alien alice environment gridlike syste...
#
#                                                  Topic8  \
# Doc1  (0.8915, wideband fading channel considered ca...
# Doc2  (0.8915, wideband fading channel considered ca...
# Doc3  (0.8128, multiple transmit antenna downlink ch...
# Doc4  (0.8128, multiple transmit antenna downlink ch...
# Doc5  (0.8066, shown mutual information curve coded ...
#
#                                                  Topic9  \
# Doc1  (0.9367, experimental evidence suggests foldin...
# Doc2  (0.921, kinesin motor protein destabilize micr...
# Doc3  (0.9208, zincfingers widely exist eukaryotic c...
# Doc4  (0.9162, development tumor known result accumu...
# Doc5  (0.9159, leishmania lipophosphoglycan molecule...
#
#                                                 Topic10  \
# Doc1  (0.9128, consider class semiparametric regress...
# Doc2  (0.9128, consider class semiparametric regress...
# Doc3  (0.9034, consider inference procedure conditio...
# Doc4  (0.8952, wang tchetgen tchetgen studied identi...
# Doc5  (0.8918, paper considers panel data model cond...
#
#                                                 Topic11  \
# Doc1  (0.9163, analysis alfven wave generation assoc...
# Doc2  (0.9113, paper examine suprathermal ion measur...
# Doc3  (0.9107, recent result van allen probe mission...
# Doc4  (0.9088, present first observation large ampli...
# Doc5  (0.9037, convection inside magnetosphere regar...
#
#                                                 Topic12  \
# Doc1  (0.8656, present study focused effect trunk ex...
# Doc2  (0.8198, many complex human natural phenomenon...
# Doc3  (0.7926, aim present study ass effect plantarf...
# Doc4  (0.7921, purpose present experiment investigat...
# Doc5  (0.7482, separate study reported postural cont...
#
#                                                 Topic13  \
# Doc1  (0.948, hausdorff topological group gtau calle...
# Doc2  (0.942, prove algebraic hypersurfaces defined ...
# Doc3  (0.9354, topological group gmu class mathcal m...
# Doc4  (0.9299, thesis develop cohomology diagram alg...
# Doc5  (0.9291, previous work citeas showed attach po...
#
#                                                 Topic14  \
# Doc1  (0.9064, propose model credit market random de...
# Doc2  (0.9003, develop finite horizon continuous tim...
# Doc3  (0.8983, study robust double auction mechanism...
# Doc4  (0.8879, study impact central clearing overthe...
# Doc5  (0.8801, consider partially asymmetric threepl...
#
#                                                 Topic15
# Doc1  (0.8645, present special solution discrete pai...
# Doc2  (0.8446, advection equation basis mathematical...
# Doc3  (0.8441, socalled direct approach separation v...
# Doc4  (0.8404, study class quadratically nonlinear w...
# Doc5  (0.8382, extending clarksonkruskals direct sim...

# %% [markdown]
# Train and Evaluate NMF Models with Different Hyperparameters

# %%
def evaluate_nmf_model(nmf, data, vectorizer, docs, ndocs=5, nwords=10):
    feature_names = vectorizer.get_feature_names_out()
    # Reconstruction error
    reconstruction_error = mean_squared_error(
        data.toarray(),
        nmf.inverse_transform(nmf.transform(data))
    )
    
    # Sparsity: proportion of non-zero elements in W and H
    W = nmf.transform(data)
    H = nmf.components_
    sparsity_W = np.mean(W != 0)
    sparsity_H = np.mean(H != 0)
    
    # Generate word-topic and document-topic tables for interpretability
    W_df, H_df = get_topics(nmf, data, feature_names, docs, ndocs, nwords)
    
    return reconstruction_error, sparsity_W, sparsity_H, W_df, H_df


def train_and_evaluate_nmf_models(data, vectorizer, docs, num_topics_list, ndocs=5, nwords=10):
    """
    Train and evaluate NMF models with specified numbers of topics.
    """
    results = []
    feature_names = vectorizer.get_feature_names_out()
    
    for num_topics in num_topics_list:
        print(f"\nTraining NMF with {num_topics} topics...")
        nmf = NMF(n_components=num_topics, random_state=42, max_iter=10, init="nndsvd")
        nmf.fit(data)
        
        # Evaluate the model
        reconstruction_error, sparsity_W, sparsity_H, W_df, H_df = evaluate_nmf_model(
            nmf, data, vectorizer, docs, ndocs, nwords
        )
        
        # Store results
        results.append({
            "num_topics": num_topics,
            "reconstruction_error": reconstruction_error,
            "sparsity_W": sparsity_W,
            "sparsity_H": sparsity_H,
            "word_topic_table": W_df,
            "doc_topic_table": H_df
        })
        
        print(f"\nReconstruction Error: {reconstruction_error:.4f}")
        print(f"Sparsity (W): {sparsity_W:.4f}")
        print(f"Sparsity (H): {sparsity_H:.4f}")
        print("\nWord-Topic Table:")
        print(W_df)
        print("\nDocument-Topic Table:")
        print(H_df)
    
    return results


# Define the list of numbers of topics
num_topics_list_nmf = [15, 20, 25, 30]
docs = df  

# Train and evaluate NMF models
nmf_results = train_and_evaluate_nmf_models(tfidf_data, tfidf_vectorizer, docs, num_topics_list_nmf)

# Select the best model based on reconstruction error
best_nmf_model = min(nmf_results, key=lambda x: x["reconstruction_error"])

print("\nBest NMF Model:")
print(f"Number of Topics: {best_nmf_model['num_topics']}")
print(f"Reconstruction Error: {best_nmf_model['reconstruction_error']:.4f}")
print(f"Sparsity (W): {best_nmf_model['sparsity_W']:.4f}")
print(f"Sparsity (H): {best_nmf_model['sparsity_H']:.4f}")
print("\nWord-Topic Table for Best Model:")
print(best_nmf_model["word_topic_table"])
print("\nDocument-Topic Table for Best Model:")
print(best_nmf_model["doc_topic_table"])
# Out:
# Training NMF with 15 topics...
#
# Reconstruction Error: 0.0001
# Sparsity (W): 0.5074
# Sparsity (H): 0.3895
#
# Word-Topic Table:
#                        Topic1                Topic2                 Topic3  \
# Word1          (0.0101, data)         (0.0102, set)       (0.0077, energy)
# Word2   (0.0047, information)       (0.01, theorem)        (0.0061, phase)
# Word3         (0.0043, paper)       (0.0086, prove)        (0.0054, field)
# Word4          (0.0043, user)    (0.0081, manifold)  (0.0053, temperature)
# Word5   (0.0038, application)        (0.008, proof)        (0.0051, state)
# Word6      (0.0036, analysis)       (0.0065, point)     (0.0051, magnetic)
# Word7      (0.0035, approach)        (0.0064, give)     (0.0042, electron)
# Word8        (0.0035, design)         (0.0064, map)   (0.0041, transition)
# Word9   (0.0033, performance)         (0.0063, let)       (0.0038, effect)
# Word10     (0.0031, research)  (0.0063, polynomial)         (0.0036, wave)
#
#                         Topic4                Topic5                Topic6  \
# Word1       (0.0411, equation)       (0.0521, model)      (0.0882, system)
# Word2        (0.0375, problem)      (0.0124, market)     (0.0174, control)
# Word3       (0.0349, solution)       (0.0116, price)     (0.0078, dynamic)
# Word4   (0.0098, differential)  (0.0074, volatility)       (0.0077, state)
# Word5      (0.0085, nonlinear)        (0.0063, risk)   (0.0066, nonlinear)
# Word6        (0.0083, optimal)     (0.0062, process)   (0.0065, dynamical)
# Word7      (0.0057, numerical)       (0.006, option)   (0.0054, stability)
# Word8           (0.0055, case)     (0.0057, dynamic)  (0.0052, controller)
# Word9       (0.005, condition)  (0.0055, stochastic)       (0.0048, power)
# Word10          (0.005, solve)   (0.0054, parameter)      (0.0045, linear)
#
#                      Topic7                  Topic8               Topic9  \
# Word1     (0.0737, network)     (0.0757, algorithm)     (0.0552, method)
# Word2        (0.0127, node)       (0.0098, problem)      (0.0208, image)
# Word3      (0.0102, neural)        (0.0089, matrix)   (0.0104, proposed)
# Word4      (0.0068, social)          (0.0086, time)       (0.007, based)
# Word5   (0.0052, structure)     (0.008, complexity)      (0.0069, using)
# Word6      (0.005, dynamic)    (0.0078, polynomial)   (0.0069, approach)
# Word7        (0.0044, gene)   (0.0053, performance)  (0.0062, technique)
# Word8    (0.0043, topology)         (0.005, number)       (0.0055, used)
# Word9        (0.0041, link)      (0.005, efficient)     (0.0052, signal)
# Word10       (0.0039, cell)  (0.0047, optimization)  (0.0049, numerical)
#
#                         Topic10                   Topic11  \
# Word1           (0.1226, group)         (0.1056, algebra)
# Word2        (0.0187, subgroup)             (0.0286, lie)
# Word3          (0.0113, finite)  (0.0133, representation)
# Word4   (0.011, representation)          (0.0112, module)
# Word5            (0.0095, free)             (0.011, hopf)
# Word6          (0.0093, action)            (0.01, matrix)
# Word7         (0.0081, abelian)        (0.0093, operator)
# Word8             (0.0078, lie)      (0.0071, cohomology)
# Word9           (0.0069, class)        (0.0067, category)
# Word10       (0.0067, finitely)          (0.0064, affine)
#
#                        Topic12                Topic13              Topic14  \
# Word1       (0.0269, function)        (0.1101, space)    (0.0463, quantum)
# Word2   (0.0223, distribution)         (0.02, metric)     (0.0425, theory)
# Word3      (0.0149, estimator)       (0.0175, banach)      (0.0169, field)
# Word4    (0.0099, probability)     (0.0121, operator)  (0.0101, classical)
# Word5          (0.0089, bound)      (0.0105, compact)   (0.0085, mechanic)
# Word6        (0.0088, channel)     (0.0095, subspace)      (0.0075, gauge)
# Word7         (0.0082, random)      (0.0089, hilbert)     (0.0062, physic)
# Word8          (0.0069, error)       (0.0082, vector)     (0.0054, string)
# Word9           (0.0068, rate)  (0.0078, topological)    (0.0051, gravity)
# Word10     (0.006, asymptotic)     (0.0068, property)    (0.005, symmetry)
#
#                    Topic15
# Word1      (0.1119, graph)
# Word2     (0.0241, vertex)
# Word3       (0.0183, edge)
# Word4       (0.0101, tree)
# Word5     (0.0092, number)
# Word6      (0.0079, bound)
# Word7        (0.0079, set)
# Word8    (0.0078, problem)
# Word9   (0.0072, directed)
# Word10    (0.0061, planar)
#
# Document-Topic Table:
#                                                  Topic1  \
# Doc1  (0.0582, year hera machine experiment performe...
# Doc2  (0.0574, current research biology heavily depe...
# Doc3  (0.0559, web community introduced set standard...
# Doc4  (0.0536, integrating open data source yield hi...
# Doc5  (0.053, internet worldwide web vast number inf...
#
#                                                  Topic2  \
# Doc1  (0.0748, prove theorem following form asubsete...
# Doc2  (0.0748, work show teichmuller distance elemen...
# Doc3  (0.0744, consider compact manifold dimension l...
# Doc4  (0.0731, let uato bounded linear operator two ...
# Doc5  (0.0728, let dsubsetsubsetmathbbcn complex man...
#
#                                                  Topic3  \
# Doc1  (0.0928, used resistivity measurement study ma...
# Doc2  (0.0903, study ferromagnetism repulsively inte...
# Doc3  (0.0897, fege lightly doped compound based fer...
# Doc4  (0.0877, mobility excess electron dense argon ...
# Doc5  (0.0873, energy loss test gyratory particle co...
#
#                                                  Topic4  \
# Doc1  (0.1306, solving diffusion problem common cons...
# Doc2  (0.1213, equation partialtuupartialxxucpartial...
# Doc3  (0.1213, equation partialtuupartialxxucpartial...
# Doc4  (0.1205, study cauchy problem korteweg vries k...
# Doc5  (0.1152, general helfrich shape equation deter...
#
#                                                  Topic5  \
# Doc1  (0.1226, propose new approach model compositio...
# Doc2  (0.1125, aim paper present describe simlab sim...
# Doc3  (0.1115, computer simulation amphiphilic syste...
# Doc4  (0.111, paper develop stochastic volatility pl...
# Doc5  (0.1094, exact path simulation underlying stat...
#
#                                                  Topic6  \
# Doc1  (0.1537, one may define complex system system ...
# Doc2  (0.1465, consider basic feature complex dynami...
# Doc3  (0.1403, power system usually large nonlinear ...
# Doc4  (0.134, feedback important concept control sys...
# Doc5  (0.1318, system approach first step towards an...
#
#                                                  Topic7  \
# Doc1  (0.1701, many real network understood two comp...
# Doc2  (0.1564, yehuda vardi introduced term network ...
# Doc3  (0.1553, goal determine structural difference ...
# Doc4  (0.1551, analogous biological sequence compari...
# Doc5  (0.1506, social network grows period time form...
#
#                                                  Topic8  \
# Doc1  (0.1244, study computational aspect nonparamet...
# Doc2  (0.1062, gvw algorithm presented gao signature...
# Doc3  (0.1039, give sublineartime approximation algo...
# Doc4  (0.1012, paper investigates decoding binary li...
# Doc5  (0.1012, paper investigates decoding binary li...
#
#                                                  Topic9  \
# Doc1  (0.1191, block matching bmd method among state...
# Doc2  (0.1126, propose new method preconditioning ka...
# Doc3  (0.1033, compared traditional empirical mode d...
# Doc4  (0.1021, study present method measure change t...
# Doc5  (0.1021, paper study alternating direction met...
#
#                                                 Topic10  \
# Doc1  (0.1789, prove permutation group different fin...
# Doc2  (0.1724, paper mainly concerned study polariza...
# Doc3  (0.1724, paper mainly concerned study polariza...
# Doc4  (0.1706, study group homotopy class self map c...
# Doc5  (0.1685, various descending chain subgroup fin...
#
#                                                 Topic11  \
# Doc1  (0.2019, paper give example generalized massey...
# Doc2  (0.1982, quotient algebra tensor algebra give ...
# Doc3  (0.1936, elliptic current algebra eqphatg arbi...
# Doc4  (0.1895, well known poisson lie algebra isomor...
# Doc5  (0.1895, analogy definition group triality int...
#
#                                                 Topic12  \
# Doc1  (0.1443, derive asymptotic normality kernel ty...
# Doc2  (0.1443, derive asymptotic normality kernel ty...
# Doc3  (0.1394, note boole algebra two element define...
# Doc4  (0.1392, consider goodnessoffit test symmetric...
# Doc5  (0.1392, consider goodnessoffit test symmetric...
#
#                                                 Topic13  \
# Doc1  (0.1718, paper continue study pclosed space cl...
# Doc2  (0.1685, paper deal pretangent space general m...
# Doc3  (0.1668, given compact manifold set simple man...
# Doc4  (0.1654, introduce notion acf space space gene...
# Doc5  (0.1614, aim paper continue study sgcompact sp...
#
#                                                 Topic14  \
# Doc1  (0.2074, agenda quantum algorithmic informatio...
# Doc2  (0.1945, body theory completely different rela...
# Doc3  (0.1659, new approach suggested quantum differ...
# Doc4  (0.1629, book review quantum field theory lewi...
# Doc5  (0.162, quantum topology deal general quantum ...
#
#                                                 Topic15
# Doc1  (0.2432, characterisation interval graph compa...
# Doc2  (0.2429, generalize treeconfluent graph broade...
# Doc3  (0.2395, integer conditional krcoloring graph ...
# Doc4  (0.2391, extend notion psparse graph previousl...
# Doc5  (0.2321, show graph size complete graph hdecom...
#
# Training NMF with 20 topics...
#
# Reconstruction Error: 0.0001
# Sparsity (W): 0.4813
# Sparsity (H): 0.3571
#
# Word-Topic Table:
#                        Topic1              Topic2                 Topic3  \
# Word1          (0.0116, data)        (0.011, set)       (0.0091, energy)
# Word2   (0.0052, information)    (0.011, theorem)        (0.0069, phase)
# Word3          (0.0051, user)  (0.0096, manifold)  (0.0061, temperature)
# Word4         (0.0044, paper)     (0.0093, prove)        (0.0056, state)
# Word5   (0.0043, application)     (0.0087, proof)   (0.0045, transition)
# Word6      (0.0038, analysis)       (0.0072, map)     (0.0044, electron)
# Word7      (0.0036, research)      (0.007, point)         (0.0041, mass)
# Word8        (0.0034, design)      (0.0067, give)       (0.0039, effect)
# Word9   (0.0034, performance)     (0.0066, class)     (0.0038, spectrum)
# Word10     (0.0033, software)       (0.0062, let)      (0.0037, density)
#
#                         Topic4                Topic5                Topic6  \
# Word1       (0.0698, equation)       (0.0615, model)       (0.091, system)
# Word2       (0.0362, solution)      (0.0144, market)     (0.0178, control)
# Word3   (0.0158, differential)       (0.0139, price)      (0.007, dynamic)
# Word4      (0.0133, nonlinear)  (0.0089, volatility)       (0.0068, state)
# Word5           (0.0095, wave)      (0.0075, option)   (0.0062, dynamical)
# Word6        (0.0074, soliton)        (0.0061, risk)   (0.0054, nonlinear)
# Word7      (0.0067, numerical)      (0.006, process)       (0.0052, power)
# Word8     (0.006, schrodinger)  (0.0059, stochastic)  (0.0052, controller)
# Word9      (0.0055, condition)     (0.0057, dynamic)   (0.0051, stability)
# Word10         (0.005, linear)     (0.0054, pricing)       (0.005, design)
#
#                      Topic7                 Topic8               Topic9  \
# Word1     (0.0827, network)    (0.0897, algorithm)     (0.0548, method)
# Word2        (0.0144, node)         (0.0109, time)      (0.0206, image)
# Word3      (0.0114, neural)   (0.0081, polynomial)    (0.011, proposed)
# Word4      (0.0077, social)    (0.008, complexity)   (0.0074, approach)
# Word5   (0.0054, structure)  (0.0054, performance)      (0.0073, based)
# Word6    (0.0048, topology)       (0.0054, number)       (0.007, using)
# Word7        (0.0046, link)    (0.0053, efficient)  (0.0065, technique)
# Word8     (0.0045, dynamic)          (0.0052, new)     (0.0064, signal)
# Word9      (0.004, traffic)      (0.0051, present)       (0.0056, used)
# Word10   (0.0039, wireless)         (0.0048, tree)  (0.0049, numerical)
#
#                          Topic10                   Topic11  \
# Word1             (0.126, group)         (0.1089, algebra)
# Word2         (0.0192, subgroup)             (0.0295, lie)
# Word3   (0.0117, representation)  (0.0134, representation)
# Word4           (0.0116, finite)          (0.0122, module)
# Word5             (0.0098, free)            (0.0113, hopf)
# Word6           (0.0094, action)        (0.0091, operator)
# Word7          (0.0083, abelian)      (0.0077, cohomology)
# Word8              (0.0079, lie)        (0.0074, category)
# Word9          (0.007, finitely)          (0.0067, affine)
# Word10           (0.0067, class)       (0.0062, structure)
#
#                         Topic12               Topic13               Topic14  \
# Word1        (0.1107, function)       (0.1168, space)     (0.0535, quantum)
# Word2      (0.0105, polynomial)      (0.0206, metric)      (0.0429, theory)
# Word3         (0.0101, formula)      (0.0186, banach)   (0.0109, classical)
# Word4     (0.0083, correlation)    (0.0137, operator)    (0.0095, mechanic)
# Word5        (0.0077, integral)     (0.0106, compact)       (0.0083, state)
# Word6           (0.0072, value)    (0.0101, subspace)       (0.0067, gauge)
# Word7        (0.0061, variable)     (0.0095, hilbert)      (0.0066, physic)
# Word8            (0.0058, term)      (0.0088, vector)     (0.0052, gravity)
# Word9   (0.0055, approximation)  (0.008, topological)      (0.0051, string)
# Word10     (0.0052, derivative)    (0.0069, property)  (0.0049, relativity)
#
#                    Topic15                    Topic16              Topic17  \
# Word1      (0.1194, graph)            (0.0965, field)       (0.0371, cell)
# Word2     (0.0256, vertex)         (0.0477, magnetic)    (0.0144, protein)
# Word3       (0.0195, edge)         (0.0108, electric)       (0.0086, gene)
# Word4       (0.0106, tree)           (0.0083, vector)     (0.0057, growth)
# Word5       (0.01, number)           (0.0078, plasma)  (0.0051, mechanism)
# Word6   (0.0077, directed)             (0.0074, ring)     (0.005, dynamic)
# Word7        (0.0074, set)   (0.0058, characteristic)        (0.0049, dna)
# Word8      (0.0072, bound)  (0.0053, electromagnetic)   (0.0047, cellular)
# Word9     (0.0064, planar)          (0.0051, current)   (0.0046, membrane)
# Word10      (0.0062, node)             (0.0051, spin)   (0.0044, sequence)
#
#                      Topic18                 Topic19               Topic20
# Word1      (0.0606, problem)  (0.0348, distribution)      (0.0722, matrix)
# Word2      (0.0161, optimal)     (0.0226, estimator)        (0.0232, code)
# Word3      (0.011, solution)   (0.0128, probability)     (0.0186, channel)
# Word4   (0.01, optimization)        (0.0102, random)    (0.0127, operator)
# Word5   (0.0087, constraint)     (0.0094, parameter)       (0.0127, bound)
# Word6     (0.0086, strategy)    (0.0086, estimation)  (0.0111, eigenvalue)
# Word7       (0.008, control)        (0.0076, sample)  (0.0082, polynomial)
# Word8        (0.0067, solve)    (0.0073, asymptotic)      (0.0062, linear)
# Word9         (0.006, paper)    (0.0066, likelihood)       (0.0056, block)
# Word10   (0.0059, portfolio)       (0.0066, density)    (0.0056, decoding)
#
# Document-Topic Table:
#                                                  Topic1  \
# Doc1  (0.0518, year hera machine experiment performe...
# Doc2  (0.051, current research biology heavily depen...
# Doc3  (0.0507, web community introduced set standard...
# Doc4  (0.0477, integrating open data source yield hi...
# Doc5  (0.046, internet worldwide web vast number inf...
#
#                                                  Topic2  \
# Doc1  (0.0729, prove theorem following form asubsete...
# Doc2  (0.0726, consider compact manifold dimension l...
# Doc3  (0.0704, prove direct analogue classical duflo...
# Doc4  (0.0696, article concerned compute cohomology ...
# Doc5  (0.0691, work show teichmuller distance elemen...
#
#                                                  Topic3  \
# Doc1  (0.0866, investigate thermodynamic property di...
# Doc2  (0.0858, quantum state twocomponent fermi trap...
# Doc3  (0.0857, effect uncompensated gav codoping str...
# Doc4  (0.0854, review leading momentum frequency tem...
# Doc5  (0.0847, small lanthanide cluster interesting ...
#
#                                                  Topic4  \
# Doc1  (0.1381, general helfrich shape equation deter...
# Doc2  (0.1379, define system dynamical differential ...
# Doc3  (0.1329, general lattice boltzmann model propo...
# Doc4  (0.1301, solving diffusion problem common cons...
# Doc5  (0.1284, extended system governed partial diff...
#
#                                                  Topic5  \
# Doc1  (0.122, propose new approach model composition...
# Doc2  (0.1119, paper develop stochastic volatility p...
# Doc3  (0.1117, aim paper present describe simlab sim...
# Doc4  (0.1111, computer simulation amphiphilic syste...
# Doc5  (0.109, parallel programming model exist abstr...
#
#                                                  Topic6  \
# Doc1  (0.1513, one may define complex system system ...
# Doc2  (0.1435, consider basic feature complex dynami...
# Doc3  (0.1373, power system usually large nonlinear ...
# Doc4  (0.1306, feedback important concept control sy...
# Doc5  (0.1301, system approach first step towards an...
#
#                                                  Topic7  \
# Doc1  (0.1618, many real network understood two comp...
# Doc2  (0.1488, yehuda vardi introduced term network ...
# Doc3  (0.1473, goal determine structural difference ...
# Doc4  (0.1459, analogous biological sequence compari...
# Doc5  (0.1435, social network grows period time form...
#
#                                                  Topic8  \
# Doc1  (0.1202, study computational aspect nonparamet...
# Doc2  (0.1031, gvw algorithm presented gao signature...
# Doc3  (0.098, signaturebased algorithm popular kind ...
# Doc4  (0.0975, famous algorithm computing grobner ba...
# Doc5  (0.0969, give sublineartime approximation algo...
#
#                                                  Topic9  \
# Doc1  (0.1148, block matching bmd method among state...
# Doc2  (0.1054, propose new method preconditioning ka...
# Doc3  (0.1008, compared traditional empirical mode d...
# Doc4  (0.0987, paper study alternating direction met...
# Doc5  (0.0979, study present method measure change t...
#
#                                                 Topic10  \
# Doc1  (0.1762, prove permutation group different fin...
# Doc2  (0.17, paper mainly concerned study polarizati...
# Doc3  (0.17, paper mainly concerned study polarizati...
# Doc4  (0.1679, study group homotopy class self map c...
# Doc5  (0.1664, various descending chain subgroup fin...
#
#                                                 Topic11  \
# Doc1  (0.1894, paper give example generalized massey...
# Doc2  (0.1859, quotient algebra tensor algebra give ...
# Doc3  (0.1816, elliptic current algebra eqphatg arbi...
# Doc4  (0.1777, well known poisson lie algebra isomor...
# Doc5  (0.1772, analogy definition group triality int...
#
#                                                 Topic12  \
# Doc1  (0.1982, paper small survey presented eighteen...
# Doc2  (0.1662, paper propose study family sparsityin...
# Doc3  (0.1597, realvalued nonnegative logconcave fun...
# Doc4  (0.1502, treatise investigates holomorphic fun...
# Doc5  (0.1476, paper consider situation given logica...
#
#                                                 Topic13  \
# Doc1  (0.162, paper continue study pclosed space cla...
# Doc2  (0.1598, paper deal pretangent space general m...
# Doc3  (0.1575, given compact manifold set simple man...
# Doc4  (0.1556, introduce notion acf space space gene...
# Doc5  (0.1528, aim paper continue study sgcompact sp...
#
#                                                 Topic14  \
# Doc1  (0.2127, agenda quantum algorithmic informatio...
# Doc2  (0.1865, body theory completely different rela...
# Doc3  (0.1725, new approach suggested quantum differ...
# Doc4  (0.1681, quantum topology deal general quantum...
# Doc5  (0.1637, nonlinear dynamic chaos theory quantu...
#
#                                                 Topic15  \
# Doc1  (0.2294, characterisation interval graph compa...
# Doc2  (0.2289, generalize treeconfluent graph broade...
# Doc3  (0.226, integer conditional krcoloring graph p...
# Doc4  (0.2252, extend notion psparse graph previousl...
# Doc5  (0.2187, show graph size complete graph hdecom...
#
#                                                 Topic16  \
# Doc1  (0.1927, intense magnetic field time breaking ...
# Doc2  (0.1767, describe technique probing statistica...
# Doc3  (0.1737, magnetic interaction weighing sample ...
# Doc4  (0.1727, consider influence electronelectron i...
# Doc5  (0.1614, method presented profiling magnetic f...
#
#                                                 Topic17  \
# Doc1  (0.2288, previous paper introduced phenomenolo...
# Doc2  (0.2187, multicellular organism several cell s...
# Doc3  (0.212, identify protein involved cellular ada...
# Doc4  (0.2062, cellular phenotype characterized diff...
# Doc5  (0.2038, developed method combining microfluid...
#
#                                                 Topic18  \
# Doc1  (0.1556, analyze problem computing correlated ...
# Doc2  (0.1514, paper problem finding sparsest minimu...
# Doc3  (0.1415, paper present general class dynamic s...
# Doc4              (0.1405, problem testology discussed)
# Doc5  (0.1367, wellknown eulerian path problem solve...
#
#                                                 Topic19  \
# Doc1  (0.1228, saltboxroof parametric probability di...
# Doc2  (0.1193, new fiveparameter continuous distribu...
# Doc3  (0.1186, derive asymptotic normality kernel ty...
# Doc4  (0.1186, derive asymptotic normality kernel ty...
# Doc5  (0.1181, article estimation reliability system...
#
#                                                 Topic20
# Doc1  (0.1782, ntimes matrix certain signsymmetric s...
# Doc2  (0.1751, generalized inversion block matrix ob...
# Doc3  (0.1716, assembled java package known matrixpa...
# Doc4  (0.1672, wiedemanns paper introducing algorith...
# Doc5  (0.1672, present explicit inverse two brownian...
#
# Training NMF with 25 topics...
#
# Reconstruction Error: 0.0001
# Sparsity (W): 0.4649
# Sparsity (H): 0.3399
#
# Word-Topic Table:
#                        Topic1              Topic2                 Topic3  \
# Word1          (0.0118, data)       (0.0127, set)       (0.0113, energy)
# Word2          (0.0054, user)   (0.0114, theorem)          (0.01, phase)
# Word3   (0.0048, information)  (0.0107, manifold)  (0.0082, temperature)
# Word4   (0.0048, application)     (0.0098, prove)         (0.008, state)
# Word5         (0.0047, paper)     (0.0089, proof)   (0.0066, transition)
# Word6      (0.0039, research)     (0.0082, point)     (0.0057, electron)
# Word7      (0.0039, analysis)       (0.0077, map)  (0.0048, interaction)
# Word8      (0.0039, approach)       (0.0075, let)       (0.0047, effect)
# Word9        (0.0038, design)     (0.0072, class)         (0.0042, wave)
# Word10     (0.0038, software)    (0.0064, result)      (0.0042, density)
#
#                         Topic4                Topic5  \
# Word1        (0.0753, problem)       (0.1038, model)
# Word2       (0.0253, solution)   (0.0094, parameter)
# Word3        (0.0148, optimal)     (0.0065, dynamic)
# Word4   (0.0112, optimization)  (0.0056, simulation)
# Word5     (0.0093, constraint)  (0.0049, stochastic)
# Word6          (0.0082, solve)    (0.0044, approach)
# Word7        (0.0066, control)     (0.0044, process)
# Word8       (0.0064, consider)       (0.0041, based)
# Word9       (0.0063, approach)  (0.0041, prediction)
# Word10      (0.0061, strategy)    (0.0037, modeling)
#
#                           Topic6               Topic7                 Topic8  \
# Word1         (0.0779, equation)    (0.0858, network)    (0.0922, algorithm)
# Word2         (0.0295, solution)       (0.0148, node)         (0.0108, time)
# Word3     (0.0173, differential)     (0.0118, neural)   (0.0081, complexity)
# Word4        (0.0147, nonlinear)     (0.0081, social)   (0.0074, polynomial)
# Word5             (0.0106, wave)  (0.0053, structure)    (0.0056, efficient)
# Word6          (0.0083, soliton)   (0.0049, topology)  (0.0056, performance)
# Word7      (0.0063, schrodinger)    (0.0049, dynamic)       (0.0053, number)
# Word8        (0.0061, numerical)       (0.0047, link)          (0.0053, new)
# Word9   (0.0056, transformation)     (0.004, traffic)      (0.0051, present)
# Word10          (0.0055, motion)      (0.0039, agent)         (0.0049, tree)
#
#                      Topic9                  Topic10  ...  \
# Word1      (0.0766, method)          (0.1284, group)  ...
# Word2    (0.0111, proposed)       (0.0195, subgroup)  ...
# Word3    (0.0084, approach)  (0.012, representation)  ...
# Word4       (0.0082, based)         (0.0112, finite)  ...
# Word5       (0.0077, using)           (0.0099, free)  ...
# Word6   (0.0076, numerical)         (0.0095, action)  ...
# Word7        (0.0061, used)        (0.0083, abelian)  ...
# Word8         (0.0058, new)             (0.008, lie)  ...
# Word9   (0.0055, technique)       (0.0069, finitely)  ...
# Word10      (0.0051, error)          (0.0065, class)  ...
#
#                           Topic16              Topic17                Topic18  \
# Word1             (0.0951, field)       (0.0367, cell)      (0.0342, channel)
# Word2           (0.048, magnetic)    (0.0145, protein)          (0.029, code)
# Word3          (0.0108, electric)       (0.0086, gene)         (0.023, bound)
# Word4            (0.0083, plasma)     (0.0057, growth)         (0.0108, rate)
# Word5            (0.0082, vector)  (0.0051, mechanism)     (0.0104, capacity)
# Word6   (0.0055, electromagnetic)         (0.005, dna)        (0.0102, error)
# Word7            (0.0054, theory)    (0.0048, dynamic)       (0.0096, scheme)
# Word8           (0.0054, current)   (0.0046, sequence)  (0.0085, information)
# Word9    (0.0053, characteristic)   (0.0046, cellular)     (0.0084, decoding)
# Word10         (0.0049, external)    (0.0045, process)        (0.0078, upper)
#
#                      Topic19                 Topic20                 Topic21  \
# Word1       (0.0303, market)  (0.0376, distribution)      (0.1193, function)
# Word2        (0.0266, price)     (0.0224, estimator)    (0.0104, polynomial)
# Word3       (0.0135, option)   (0.0135, probability)       (0.0091, formula)
# Word4   (0.0126, volatility)        (0.0115, random)      (0.0082, integral)
# Word5         (0.0125, risk)     (0.0092, parameter)   (0.0078, correlation)
# Word6        (0.0109, asset)     (0.008, estimation)         (0.0063, value)
# Word7        (0.0106, stock)        (0.0075, sample)      (0.0063, variable)
# Word8    (0.0095, financial)    (0.0074, asymptotic)          (0.0059, term)
# Word9    (0.0094, portfolio)      (0.0069, variable)    (0.0053, derivative)
# Word10     (0.0089, pricing)       (0.0068, density)  (0.005, approximation)
#
#                    Topic22               Topic23                   Topic24  \
# Word1       (0.0156, star)       (0.092, matrix)           (0.0684, image)
# Word2       (0.0141, mass)    (0.0429, operator)  (0.0072, reconstruction)
# Word3     (0.0134, galaxy)  (0.0179, eigenvalue)           (0.0071, noise)
# Word4    (0.0088, cluster)    (0.0106, spectral)         (0.0069, imaging)
# Word5   (0.0069, emission)  (0.0097, polynomial)         (0.0067, quality)
# Word6     (0.0062, planet)    (0.0096, spectrum)       (0.0064, technique)
# Word7       (0.0061, disk)     (0.0067, element)        (0.0063, proposed)
# Word8       (0.0059, xray)      (0.0062, random)          (0.0059, signal)
# Word9     (0.0056, source)  (0.0058, covariance)           (0.0057, pixel)
# Word10   (0.0055, stellar)        (0.0057, rank)      (0.0052, processing)
#
#                       Topic25
# Word1      (0.1029, category)
# Word2     (0.0198, structure)
# Word3      (0.0153, monoidal)
# Word4        (0.0149, object)
# Word5      (0.0124, homotopy)
# Word6      (0.0116, functors)
# Word7       (0.0115, functor)
# Word8        (0.0113, theory)
# Word9        (0.0104, module)
# Word10  (0.0092, equivalence)
#
# [10 rows x 25 columns]
#
# Document-Topic Table:
#                                                  Topic1  \
# Doc1  (0.0438, current research biology heavily depe...
# Doc2  (0.043, web community introduced set standard ...
# Doc3  (0.0428, year hera machine experiment performe...
# Doc4  (0.039, integrating open data source yield hig...
# Doc5  (0.0388, data security major issue webbased ap...
#
#                                                  Topic2  \
# Doc1  (0.0698, consider compact manifold dimension l...
# Doc2  (0.0661, article concerned compute cohomology ...
# Doc3  (0.066, prove theorem following form asubseteq...
# Doc4  (0.0658, work show teichmuller distance elemen...
# Doc5  (0.0654, prove direct analogue classical duflo...
#
#                                                  Topic3  \
# Doc1  (0.0941, study twodimensional model quenched r...
# Doc2  (0.0935, investigate thermodynamic property di...
# Doc3  (0.0922, paper phase diagram polar spin bose g...
# Doc4  (0.0917, effect uncompensated gav codoping str...
# Doc5  (0.0912, quantum state twocomponent fermi trap...
#
#                                                  Topic4  \
# Doc1  (0.1116, paper problem finding sparsest minimu...
# Doc2  (0.1051, analyze problem computing correlated ...
# Doc3                 (0.1, problem testology discussed)
# Doc4  (0.0948, paper present general class dynamic s...
# Doc5  (0.0927, wellknown eulerian path problem solve...
#
#                                                  Topic5  \
# Doc1  (0.1332, propose new approach model compositio...
# Doc2  (0.121, computer simulation amphiphilic system...
# Doc3  (0.1209, parallel programming model exist abst...
# Doc4  (0.1177, aim paper present describe simlab sim...
# Doc5  (0.1126, often goal model selection choose mod...
#
#                                                  Topic6  \
# Doc1  (0.1593, define system dynamical differential ...
# Doc2  (0.156, general helfrich shape equation determ...
# Doc3  (0.1531, general lattice boltzmann model propo...
# Doc4  (0.1481, extended system governed partial diff...
# Doc5  (0.147, solving diffusion problem common consi...
#
#                                                  Topic7  \
# Doc1  (0.1513, many real network understood two comp...
# Doc2  (0.1395, yehuda vardi introduced term network ...
# Doc3  (0.1375, goal determine structural difference ...
# Doc4  (0.1365, analogous biological sequence compari...
# Doc5  (0.1346, social network grows period time form...
#
#                                                  Topic8  \
# Doc1  (0.1133, study computational aspect nonparamet...
# Doc2  (0.0972, gvw algorithm presented gao signature...
# Doc3  (0.0925, signaturebased algorithm popular kind...
# Doc4  (0.092, famous algorithm computing grobner bas...
# Doc5  (0.091, give sublineartime approximation algor...
#
#                                                  Topic9  \
# Doc1  (0.1065, propose new method preconditioning ka...
# Doc2  (0.0988, study present method measure change t...
# Doc3  (0.0986, present novel method calculation frac...
# Doc4  (0.0976, overview article present several meth...
# Doc5  (0.0964, introduce new iterative rootfinding m...
#
#                                                 Topic10  ...  \
# Doc1  (0.169, prove permutation group different fini...  ...
# Doc2  (0.1635, paper mainly concerned study polariza...  ...
# Doc3  (0.1635, paper mainly concerned study polariza...  ...
# Doc4  (0.161, study group homotopy class self map co...  ...
# Doc5  (0.1598, various descending chain subgroup fin...  ...
#
#                                                 Topic16  \
# Doc1  (0.1878, intense magnetic field time breaking ...
# Doc2  (0.1728, describe technique probing statistica...
# Doc3  (0.1697, magnetic interaction weighing sample ...
# Doc4  (0.1685, consider influence electronelectron i...
# Doc5  (0.158, method presented profiling magnetic fi...
#
#                                                 Topic17  \
# Doc1  (0.2038, previous paper introduced phenomenolo...
# Doc2  (0.1943, multicellular organism several cell s...
# Doc3  (0.1907, identify protein involved cellular ad...
# Doc4  (0.1851, cellular phenotype characterized diff...
# Doc5  (0.1837, developed method combining microfluid...
#
#                                                 Topic18  \
# Doc1  (0.1873, paper considers achievable rate decod...
# Doc2  (0.1873, paper considers achievable rate decod...
# Doc3  (0.1709, derive bound asymptotic density parit...
# Doc4  (0.1709, derive bound asymptotic density parit...
# Doc5  (0.1689, show extrinsic information coded bit ...
#
#                                                 Topic19  \
# Doc1  (0.1276, investigate financial market model ri...
# Doc2  (0.1265, paper present optimal allocation prob...
# Doc3  (0.1262, one shortcoming black scholes model o...
# Doc4  (0.1227, study pricing hedging european spread...
# Doc5  (0.1207, market making play crucial role provi...
#
#                                                 Topic20  \
# Doc1  (0.1226, saltboxroof parametric probability di...
# Doc2  (0.1186, new fiveparameter continuous distribu...
# Doc3  (0.115, derive asymptotic normality kernel typ...
# Doc4  (0.115, derive asymptotic normality kernel typ...
# Doc5  (0.1123, mixture density meant density form pi...
#
#                                                 Topic21  \
# Doc1  (0.1922, paper small survey presented eighteen...
# Doc2  (0.1606, paper propose study family sparsityin...
# Doc3  (0.1543, realvalued nonnegative logconcave fun...
# Doc4  (0.1451, treatise investigates holomorphic fun...
# Doc5  (0.1426, paper consider situation given logica...
#
#                                                 Topic22  \
# Doc1  (0.1694, nuclear star cluster nsc located phot...
# Doc2  (0.169, study stellar mass assembly spiderweb ...
# Doc3  (0.1612, present iram plateau bure interferome...
# Doc4  (0.158, present comprehensive analysis stellar...
# Doc5  (0.157, present observation massive star clust...
#
#                                                 Topic23  \
# Doc1  (0.1811, ntimes matrix certain signsymmetric s...
# Doc2  (0.1736, generalized inversion block matrix ob...
# Doc3  (0.1712, assembled java package known matrixpa...
# Doc4  (0.1695, develop relative oscillation theory j...
# Doc5  (0.1688, nystrom method routinely used outofsa...
#
#                                                 Topic24  \
# Doc1  (0.2383, image compression play important role...
# Doc2  (0.2329, powerful deep network architecture ge...
# Doc3  (0.223, paper attempt improve quality modifica...
# Doc4  (0.2208, due increasing requirement transmissi...
# Doc5  (0.2133, advancement image capturing device im...
#
#                                                 Topic25
# Doc1  (0.2697, construction kleisli object category ...
# Doc2  (0.2507, paper work detail closed multicategor...
# Doc3  (0.2456, popescugabriel theorem state grothend...
# Doc4  (0.237, give explicit construction category op...
# Doc5  (0.2354, generalize notion monetary value meas...
#
# [5 rows x 25 columns]
#
# Training NMF with 30 topics...
#
# Reconstruction Error: 0.0001
# Sparsity (W): 0.4399
# Sparsity (H): 0.3195
#
# Word-Topic Table:
#                        Topic1                Topic2                 Topic3  \
# Word1          (0.0128, data)         (0.0171, set)        (0.0167, phase)
# Word2           (0.006, user)     (0.0151, theorem)  (0.0122, temperature)
# Word3   (0.0052, information)       (0.0125, proof)   (0.0106, transition)
# Word4   (0.0048, application)       (0.0111, prove)        (0.0093, state)
# Word5      (0.0043, research)         (0.0097, let)       (0.007, lattice)
# Word6       (0.004, analysis)  (0.0095, polynomial)        (0.006, effect)
# Word7      (0.0039, software)        (0.0087, ring)      (0.0056, density)
# Word8      (0.0038, approach)      (0.0086, finite)         (0.0055, wave)
# Word9          (0.0036, tool)      (0.0086, number)         (0.0053, spin)
# Word10       (0.0035, design)      (0.0084, result)  (0.0051, interaction)
#
#                         Topic4                Topic5                 Topic6  \
# Word1       (0.0769, equation)       (0.0676, model)       (0.0818, system)
# Word2       (0.0485, solution)       (0.016, market)       (0.018, dynamic)
# Word3   (0.0176, differential)        (0.015, price)    (0.0131, nonlinear)
# Word4      (0.0108, nonlinear)  (0.0093, volatility)         (0.0107, type)
# Word5           (0.0087, wave)      (0.0082, option)    (0.0105, dynamical)
# Word6         (0.008, problem)        (0.0067, risk)      (0.0066, complex)
# Word7      (0.0078, numerical)     (0.0059, pricing)        (0.0065, agent)
# Word8      (0.0067, condition)       (0.0059, asset)  (0.0059, hamiltonian)
# Word9       (0.0057, boundary)  (0.0058, stochastic)  (0.0055, interaction)
# Word10   (0.0056, schrodinger)   (0.0056, parameter)   (0.0048, integrable)
#
#                      Topic7                  Topic8               Topic9  \
# Word1     (0.0964, network)     (0.0931, algorithm)      (0.077, method)
# Word2        (0.0163, node)       (0.0083, problem)   (0.0111, proposed)
# Word3      (0.0134, neural)    (0.0083, complexity)   (0.0086, approach)
# Word4      (0.0088, social)          (0.0071, time)      (0.0084, based)
# Word5   (0.0057, structure)    (0.0062, polynomial)       (0.008, using)
# Word6    (0.0055, topology)     (0.0058, efficient)  (0.0076, numerical)
# Word7        (0.0051, link)       (0.0057, present)       (0.0064, used)
# Word8     (0.0043, dynamic)        (0.0054, search)        (0.0062, new)
# Word9     (0.0042, traffic)  (0.0054, optimization)  (0.0058, technique)
# Word10    (0.0042, routing)   (0.0054, performance)      (0.005, signal)
#
#                          Topic10  ...                 Topic21  \
# Word1            (0.1327, group)  ...      (0.1246, function)
# Word2         (0.0201, subgroup)  ...       (0.0116, formula)
# Word3   (0.0122, representation)  ...      (0.0086, integral)
# Word4           (0.0115, finite)  ...   (0.0082, correlation)
# Word5             (0.0102, free)  ...         (0.0071, value)
# Word6           (0.0093, action)  ...      (0.0069, variable)
# Word7          (0.0087, abelian)  ...    (0.0068, polynomial)
# Word8            (0.0078, class)  ...          (0.0062, term)
# Word9              (0.0077, lie)  ...  (0.006, approximation)
# Word10         (0.007, finitely)  ...    (0.0058, derivative)
#
#                     Topic22                   Topic23  \
# Word1        (0.0163, star)          (0.1244, matrix)
# Word2        (0.0145, mass)      (0.0153, eigenvalue)
# Word3       (0.014, galaxy)      (0.0144, polynomial)
# Word4     (0.0094, cluster)         (0.0087, element)
# Word5    (0.0069, emission)      (0.0084, covariance)
# Word6      (0.0065, planet)           (0.008, random)
# Word7        (0.0063, disk)            (0.0077, rank)
# Word8        (0.0058, xray)          (0.0075, sparse)
# Word9     (0.0058, stellar)  (0.0068, multiplication)
# Word10  (0.0056, formation)           (0.0068, entry)
#
#                          Topic24             Topic25                Topic26  \
# Word1            (0.0706, image)    (0.0442, energy)     (0.1079, category)
# Word2   (0.0074, reconstruction)      (0.0146, beam)    (0.0197, structure)
# Word3          (0.0071, imaging)  (0.0096, electron)      (0.016, monoidal)
# Word4          (0.0067, quality)  (0.0087, particle)       (0.0156, object)
# Word5        (0.0066, technique)    (0.008, section)     (0.0131, homotopy)
# Word6            (0.0065, noise)  (0.0077, detector)     (0.0121, functors)
# Word7         (0.0061, proposed)     (0.0075, cross)       (0.012, functor)
# Word8            (0.0058, pixel)       (0.0066, mev)       (0.0108, theory)
# Word9      (0.0054, compression)    (0.0066, proton)       (0.0101, module)
# Word10      (0.0052, processing)  (0.0064, measured)  (0.0097, equivalence)
#
#                     Topic27                Topic28                Topic29  \
# Word1    (0.0495, manifold)     (0.1038, operator)    (0.1479, withdrawn)
# Word2     (0.0293, surface)        (0.0189, state)         (0.097, paper)
# Word3   (0.019, symplectic)     (0.0173, language)       (0.0896, author)
# Word4   (0.0129, structure)     (0.0131, spectrum)          (0.0246, due)
# Word5   (0.0119, invariant)   (0.0121, eigenvalue)        (0.0169, error)
# Word6       (0.0103, curve)     (0.0116, spectral)  (0.0142, publication)
# Word7      (0.0102, bundle)    (0.0082, automaton)    (0.011, submission)
# Word8     (0.0093, complex)  (0.0075, selfadjoint)      (0.0095, version)
# Word9         (0.0085, map)    (0.0073, potential)        (0.0077, arxiv)
# Word10    (0.0084, compact)  (0.0072, schrodinger)  (0.0053, preliminary)
#
#                      Topic30
# Word1         (0.0775, code)
# Word2        (0.0544, bound)
# Word3        (0.0183, upper)
# Word4         (0.016, lower)
# Word5     (0.0147, decoding)
# Word6        (0.0135, error)
# Word7       (0.0088, binary)
# Word8   (0.0085, complexity)
# Word9         (0.0078, ldpc)
# Word10      (0.0066, length)
#
# [10 rows x 30 columns]
#
# Document-Topic Table:
#                                                  Topic1  \
# Doc1  (0.0389, web community introduced set standard...
# Doc2  (0.0382, current research biology heavily depe...
# Doc3  (0.0368, year hera machine experiment performe...
# Doc4  (0.0341, integrating open data source yield hi...
# Doc5  (0.034, data security major issue webbased app...
#
#                                                  Topic2  \
# Doc1  (0.0705, proof set real number denumerable given)
# Doc2  (0.0687, prove theorem following form asubsete...
# Doc3  (0.0677, note give alternative proof following...
# Doc4  (0.0655, let ideal commutative noetherian ring...
# Doc5  (0.0651, real part hinftybt dense linftytrbt j...
#
#                                                  Topic3  \
# Doc1  (0.1178, paper phase diagram polar spin bose g...
# Doc2  (0.1171, study twodimensional model quenched r...
# Doc3  (0.1043, phase diagram metal variable carrier ...
# Doc4  (0.1018, effect uncompensated gav codoping str...
# Doc5  (0.1002, finite temperature phase diagram higg...
#
#                                                  Topic4  \
# Doc1  (0.1055, general helfrich shape equation deter...
# Doc2  (0.104, define system dynamical differential e...
# Doc3  (0.1023, solving diffusion problem common cons...
# Doc4  (0.1013, general lattice boltzmann model propo...
# Doc5  (0.0956, extended system governed partial diff...
#
#                                                  Topic5  \
# Doc1  (0.1155, propose new approach model compositio...
# Doc2  (0.1064, aim paper present describe simlab sim...
# Doc3  (0.1048, paper develop stochastic volatility p...
# Doc4  (0.1039, parallel programming model exist abst...
# Doc5  (0.1018, computer simulation amphiphilic syste...
#
#                                                  Topic6  \
# Doc1  (0.1462, one may define complex system system ...
# Doc2  (0.1217, system approach first step towards an...
# Doc3  (0.1163, system system differ traditional syst...
# Doc4  (0.1138, principle natural system biological e...
# Doc5  (0.1106, using set heterogeneous competing sys...
#
#                                                  Topic7  \
# Doc1  (0.1393, many real network understood two comp...
# Doc2  (0.1282, yehuda vardi introduced term network ...
# Doc3  (0.1267, goal determine structural difference ...
# Doc4  (0.1249, analogous biological sequence compari...
# Doc5  (0.1234, social network grows period time form...
#
#                                                  Topic8  \
# Doc1  (0.1096, study computational aspect nonparamet...
# Doc2  (0.0945, gvw algorithm presented gao signature...
# Doc3  (0.0902, signaturebased algorithm popular kind...
# Doc4  (0.0896, famous algorithm computing grobner ba...
# Doc5  (0.0888, give sublineartime approximation algo...
#
#                                                  Topic9  \
# Doc1  (0.0938, propose new method preconditioning ka...
# Doc2  (0.0868, study present method measure change t...
# Doc3  (0.0867, present novel method calculation frac...
# Doc4  (0.0861, overview article present several meth...
# Doc5  (0.085, introduce new iterative rootfinding me...
#
#                                                 Topic10  ...  \
# Doc1  (0.1671, prove permutation group different fin...  ...
# Doc2  (0.1613, paper mainly concerned study polariza...  ...
# Doc3  (0.1613, paper mainly concerned study polariza...  ...
# Doc4  (0.1592, study group homotopy class self map c...  ...
# Doc5  (0.1579, various descending chain subgroup fin...  ...
#
#                                                 Topic21  \
# Doc1  (0.1973, paper small survey presented eighteen...
# Doc2  (0.1642, paper propose study family sparsityin...
# Doc3  (0.1573, realvalued nonnegative logconcave fun...
# Doc4  (0.1488, treatise investigates holomorphic fun...
# Doc5  (0.1467, paper consider situation given logica...
#
#                                                 Topic22  \
# Doc1  (0.1435, study stellar mass assembly spiderweb...
# Doc2  (0.1428, nuclear star cluster nsc located phot...
# Doc3  (0.1371, present iram plateau bure interferome...
# Doc4  (0.1339, present comprehensive analysis stella...
# Doc5  (0.1333, present observation massive star clus...
#
#                                                 Topic23  \
# Doc1  (0.1884, ntimes matrix certain signsymmetric s...
# Doc2  (0.1863, assembled java package known matrixpa...
# Doc3  (0.1849, generalized inversion block matrix ob...
# Doc4  (0.1794, show matrix hermitian positive semide...
# Doc5  (0.179, nystrom method routinely used outofsam...
#
#                                                 Topic24  \
# Doc1  (0.2393, image compression play important role...
# Doc2  (0.2341, powerful deep network architecture ge...
# Doc3  (0.2233, paper attempt improve quality modific...
# Doc4  (0.2215, due increasing requirement transmissi...
# Doc5  (0.2136, advancement image capturing device im...
#
#                                                 Topic25  \
# Doc1  (0.1566, study reaction performed energy range...
# Doc2  (0.1457, using fopi detector gsi darmstadt exc...
# Doc3  (0.1388, measurement dielectron production col...
# Doc4  (0.1265, partition decay energy kinetic energy...
# Doc5  (0.12, event large rapidity gap total transver...
#
#                                                 Topic26  \
# Doc1  (0.2217, construction kleisli object category ...
# Doc2  (0.2044, paper work detail closed multicategor...
# Doc3  (0.2008, popescugabriel theorem state grothend...
# Doc4  (0.1939, give explicit construction category o...
# Doc5  (0.1931, generalize notion monetary value meas...
#
#                                                 Topic27  \
# Doc1  (0.1902, describe algorithm enabled give compl...
# Doc2  (0.1861, kcontact manifold smooth manifold con...
# Doc3  (0.1784, show certain class contact manifold a...
# Doc4  (0.1751, first part paper begin study polysymp...
# Doc5  (0.172, question whether riemannian manifold g...
#
#                                                 Topic28  \
# Doc1  (0.2021, spectral problem vzpsizpsi considered...
# Doc2  (0.1984, indefinite sturmliouville operator sg...
# Doc3  (0.187, construct family bispectral difference...
# Doc4  (0.1792, regular operator hilbert cmodule defi...
# Doc5  (0.1702, generalizing algebra motioninvariant ...
#
#                                Topic29  \
# Doc1  (0.3349, paper withdrawn author)
# Doc2  (0.3349, paper withdrawn author)
# Doc3  (0.3349, paper withdrawn author)
# Doc4  (0.3349, paper withdrawn author)
# Doc5  (0.3349, paper withdrawn author)
#
#                                                 Topic30
# Doc1  (0.1705, upper lower bound error probability l...
# Doc2  (0.1705, upper lower bound error probability l...
# Doc3  (0.1649, derive bound asymptotic density parit...
# Doc4  (0.1649, derive bound asymptotic density parit...
# Doc5  (0.1635, binary linear error correcting code r...
#
# [5 rows x 30 columns]
#
# Best NMF Model:
# Number of Topics: 30
# Reconstruction Error: 0.0001
# Sparsity (W): 0.4399
# Sparsity (H): 0.3195
#
# Word-Topic Table for Best Model:
#                        Topic1                Topic2                 Topic3  \
# Word1          (0.0128, data)         (0.0171, set)        (0.0167, phase)
# Word2           (0.006, user)     (0.0151, theorem)  (0.0122, temperature)
# Word3   (0.0052, information)       (0.0125, proof)   (0.0106, transition)
# Word4   (0.0048, application)       (0.0111, prove)        (0.0093, state)
# Word5      (0.0043, research)         (0.0097, let)       (0.007, lattice)
# Word6       (0.004, analysis)  (0.0095, polynomial)        (0.006, effect)
# Word7      (0.0039, software)        (0.0087, ring)      (0.0056, density)
# Word8      (0.0038, approach)      (0.0086, finite)         (0.0055, wave)
# Word9          (0.0036, tool)      (0.0086, number)         (0.0053, spin)
# Word10       (0.0035, design)      (0.0084, result)  (0.0051, interaction)
#
#                         Topic4                Topic5                 Topic6  \
# Word1       (0.0769, equation)       (0.0676, model)       (0.0818, system)
# Word2       (0.0485, solution)       (0.016, market)       (0.018, dynamic)
# Word3   (0.0176, differential)        (0.015, price)    (0.0131, nonlinear)
# Word4      (0.0108, nonlinear)  (0.0093, volatility)         (0.0107, type)
# Word5           (0.0087, wave)      (0.0082, option)    (0.0105, dynamical)
# Word6         (0.008, problem)        (0.0067, risk)      (0.0066, complex)
# Word7      (0.0078, numerical)     (0.0059, pricing)        (0.0065, agent)
# Word8      (0.0067, condition)       (0.0059, asset)  (0.0059, hamiltonian)
# Word9       (0.0057, boundary)  (0.0058, stochastic)  (0.0055, interaction)
# Word10   (0.0056, schrodinger)   (0.0056, parameter)   (0.0048, integrable)
#
#                      Topic7                  Topic8               Topic9  \
# Word1     (0.0964, network)     (0.0931, algorithm)      (0.077, method)
# Word2        (0.0163, node)       (0.0083, problem)   (0.0111, proposed)
# Word3      (0.0134, neural)    (0.0083, complexity)   (0.0086, approach)
# Word4      (0.0088, social)          (0.0071, time)      (0.0084, based)
# Word5   (0.0057, structure)    (0.0062, polynomial)       (0.008, using)
# Word6    (0.0055, topology)     (0.0058, efficient)  (0.0076, numerical)
# Word7        (0.0051, link)       (0.0057, present)       (0.0064, used)
# Word8     (0.0043, dynamic)        (0.0054, search)        (0.0062, new)
# Word9     (0.0042, traffic)  (0.0054, optimization)  (0.0058, technique)
# Word10    (0.0042, routing)   (0.0054, performance)      (0.005, signal)
#
#                          Topic10  ...                 Topic21  \
# Word1            (0.1327, group)  ...      (0.1246, function)
# Word2         (0.0201, subgroup)  ...       (0.0116, formula)
# Word3   (0.0122, representation)  ...      (0.0086, integral)
# Word4           (0.0115, finite)  ...   (0.0082, correlation)
# Word5             (0.0102, free)  ...         (0.0071, value)
# Word6           (0.0093, action)  ...      (0.0069, variable)
# Word7          (0.0087, abelian)  ...    (0.0068, polynomial)
# Word8            (0.0078, class)  ...          (0.0062, term)
# Word9              (0.0077, lie)  ...  (0.006, approximation)
# Word10         (0.007, finitely)  ...    (0.0058, derivative)
#
#                     Topic22                   Topic23  \
# Word1        (0.0163, star)          (0.1244, matrix)
# Word2        (0.0145, mass)      (0.0153, eigenvalue)
# Word3       (0.014, galaxy)      (0.0144, polynomial)
# Word4     (0.0094, cluster)         (0.0087, element)
# Word5    (0.0069, emission)      (0.0084, covariance)
# Word6      (0.0065, planet)           (0.008, random)
# Word7        (0.0063, disk)            (0.0077, rank)
# Word8        (0.0058, xray)          (0.0075, sparse)
# Word9     (0.0058, stellar)  (0.0068, multiplication)
# Word10  (0.0056, formation)           (0.0068, entry)
#
#                          Topic24             Topic25                Topic26  \
# Word1            (0.0706, image)    (0.0442, energy)     (0.1079, category)
# Word2   (0.0074, reconstruction)      (0.0146, beam)    (0.0197, structure)
# Word3          (0.0071, imaging)  (0.0096, electron)      (0.016, monoidal)
# Word4          (0.0067, quality)  (0.0087, particle)       (0.0156, object)
# Word5        (0.0066, technique)    (0.008, section)     (0.0131, homotopy)
# Word6            (0.0065, noise)  (0.0077, detector)     (0.0121, functors)
# Word7         (0.0061, proposed)     (0.0075, cross)       (0.012, functor)
# Word8            (0.0058, pixel)       (0.0066, mev)       (0.0108, theory)
# Word9      (0.0054, compression)    (0.0066, proton)       (0.0101, module)
# Word10      (0.0052, processing)  (0.0064, measured)  (0.0097, equivalence)
#
#                     Topic27                Topic28                Topic29  \
# Word1    (0.0495, manifold)     (0.1038, operator)    (0.1479, withdrawn)
# Word2     (0.0293, surface)        (0.0189, state)         (0.097, paper)
# Word3   (0.019, symplectic)     (0.0173, language)       (0.0896, author)
# Word4   (0.0129, structure)     (0.0131, spectrum)          (0.0246, due)
# Word5   (0.0119, invariant)   (0.0121, eigenvalue)        (0.0169, error)
# Word6       (0.0103, curve)     (0.0116, spectral)  (0.0142, publication)
# Word7      (0.0102, bundle)    (0.0082, automaton)    (0.011, submission)
# Word8     (0.0093, complex)  (0.0075, selfadjoint)      (0.0095, version)
# Word9         (0.0085, map)    (0.0073, potential)        (0.0077, arxiv)
# Word10    (0.0084, compact)  (0.0072, schrodinger)  (0.0053, preliminary)
#
#                      Topic30
# Word1         (0.0775, code)
# Word2        (0.0544, bound)
# Word3        (0.0183, upper)
# Word4         (0.016, lower)
# Word5     (0.0147, decoding)
# Word6        (0.0135, error)
# Word7       (0.0088, binary)
# Word8   (0.0085, complexity)
# Word9         (0.0078, ldpc)
# Word10      (0.0066, length)
#
# [10 rows x 30 columns]
#
# Document-Topic Table for Best Model:
#                                                  Topic1  \
# Doc1  (0.0389, web community introduced set standard...
# Doc2  (0.0382, current research biology heavily depe...
# Doc3  (0.0368, year hera machine experiment performe...
# Doc4  (0.0341, integrating open data source yield hi...
# Doc5  (0.034, data security major issue webbased app...
#
#                                                  Topic2  \
# Doc1  (0.0705, proof set real number denumerable given)
# Doc2  (0.0687, prove theorem following form asubsete...
# Doc3  (0.0677, note give alternative proof following...
# Doc4  (0.0655, let ideal commutative noetherian ring...
# Doc5  (0.0651, real part hinftybt dense linftytrbt j...
#
#                                                  Topic3  \
# Doc1  (0.1178, paper phase diagram polar spin bose g...
# Doc2  (0.1171, study twodimensional model quenched r...
# Doc3  (0.1043, phase diagram metal variable carrier ...
# Doc4  (0.1018, effect uncompensated gav codoping str...
# Doc5  (0.1002, finite temperature phase diagram higg...
#
#                                                  Topic4  \
# Doc1  (0.1055, general helfrich shape equation deter...
# Doc2  (0.104, define system dynamical differential e...
# Doc3  (0.1023, solving diffusion problem common cons...
# Doc4  (0.1013, general lattice boltzmann model propo...
# Doc5  (0.0956, extended system governed partial diff...
#
#                                                  Topic5  \
# Doc1  (0.1155, propose new approach model compositio...
# Doc2  (0.1064, aim paper present describe simlab sim...
# Doc3  (0.1048, paper develop stochastic volatility p...
# Doc4  (0.1039, parallel programming model exist abst...
# Doc5  (0.1018, computer simulation amphiphilic syste...
#
#                                                  Topic6  \
# Doc1  (0.1462, one may define complex system system ...
# Doc2  (0.1217, system approach first step towards an...
# Doc3  (0.1163, system system differ traditional syst...
# Doc4  (0.1138, principle natural system biological e...
# Doc5  (0.1106, using set heterogeneous competing sys...
#
#                                                  Topic7  \
# Doc1  (0.1393, many real network understood two comp...
# Doc2  (0.1282, yehuda vardi introduced term network ...
# Doc3  (0.1267, goal determine structural difference ...
# Doc4  (0.1249, analogous biological sequence compari...
# Doc5  (0.1234, social network grows period time form...
#
#                                                  Topic8  \
# Doc1  (0.1096, study computational aspect nonparamet...
# Doc2  (0.0945, gvw algorithm presented gao signature...
# Doc3  (0.0902, signaturebased algorithm popular kind...
# Doc4  (0.0896, famous algorithm computing grobner ba...
# Doc5  (0.0888, give sublineartime approximation algo...
#
#                                                  Topic9  \
# Doc1  (0.0938, propose new method preconditioning ka...
# Doc2  (0.0868, study present method measure change t...
# Doc3  (0.0867, present novel method calculation frac...
# Doc4  (0.0861, overview article present several meth...
# Doc5  (0.085, introduce new iterative rootfinding me...
#
#                                                 Topic10  ...  \
# Doc1  (0.1671, prove permutation group different fin...  ...
# Doc2  (0.1613, paper mainly concerned study polariza...  ...
# Doc3  (0.1613, paper mainly concerned study polariza...  ...
# Doc4  (0.1592, study group homotopy class self map c...  ...
# Doc5  (0.1579, various descending chain subgroup fin...  ...
#
#                                                 Topic21  \
# Doc1  (0.1973, paper small survey presented eighteen...
# Doc2  (0.1642, paper propose study family sparsityin...
# Doc3  (0.1573, realvalued nonnegative logconcave fun...
# Doc4  (0.1488, treatise investigates holomorphic fun...
# Doc5  (0.1467, paper consider situation given logica...
#
#                                                 Topic22  \
# Doc1  (0.1435, study stellar mass assembly spiderweb...
# Doc2  (0.1428, nuclear star cluster nsc located phot...
# Doc3  (0.1371, present iram plateau bure interferome...
# Doc4  (0.1339, present comprehensive analysis stella...
# Doc5  (0.1333, present observation massive star clus...
#
#                                                 Topic23  \
# Doc1  (0.1884, ntimes matrix certain signsymmetric s...
# Doc2  (0.1863, assembled java package known matrixpa...
# Doc3  (0.1849, generalized inversion block matrix ob...
# Doc4  (0.1794, show matrix hermitian positive semide...
# Doc5  (0.179, nystrom method routinely used outofsam...
#
#                                                 Topic24  \
# Doc1  (0.2393, image compression play important role...
# Doc2  (0.2341, powerful deep network architecture ge...
# Doc3  (0.2233, paper attempt improve quality modific...
# Doc4  (0.2215, due increasing requirement transmissi...
# Doc5  (0.2136, advancement image capturing device im...
#
#                                                 Topic25  \
# Doc1  (0.1566, study reaction performed energy range...
# Doc2  (0.1457, using fopi detector gsi darmstadt exc...
# Doc3  (0.1388, measurement dielectron production col...
# Doc4  (0.1265, partition decay energy kinetic energy...
# Doc5  (0.12, event large rapidity gap total transver...
#
#                                                 Topic26  \
# Doc1  (0.2217, construction kleisli object category ...
# Doc2  (0.2044, paper work detail closed multicategor...
# Doc3  (0.2008, popescugabriel theorem state grothend...
# Doc4  (0.1939, give explicit construction category o...
# Doc5  (0.1931, generalize notion monetary value meas...
#
#                                                 Topic27  \
# Doc1  (0.1902, describe algorithm enabled give compl...
# Doc2  (0.1861, kcontact manifold smooth manifold con...
# Doc3  (0.1784, show certain class contact manifold a...
# Doc4  (0.1751, first part paper begin study polysymp...
# Doc5  (0.172, question whether riemannian manifold g...
#
#                                                 Topic28  \
# Doc1  (0.2021, spectral problem vzpsizpsi considered...
# Doc2  (0.1984, indefinite sturmliouville operator sg...
# Doc3  (0.187, construct family bispectral difference...
# Doc4  (0.1792, regular operator hilbert cmodule defi...
# Doc5  (0.1702, generalizing algebra motioninvariant ...
#
#                                Topic29  \
# Doc1  (0.3349, paper withdrawn author)
# Doc2  (0.3349, paper withdrawn author)
# Doc3  (0.3349, paper withdrawn author)
# Doc4  (0.3349, paper withdrawn author)
# Doc5  (0.3349, paper withdrawn author)
#
#                                                 Topic30
# Doc1  (0.1705, upper lower bound error probability l...
# Doc2  (0.1705, upper lower bound error probability l...
# Doc3  (0.1649, derive bound asymptotic density parit...
# Doc4  (0.1649, derive bound asymptotic density parit...
# Doc5  (0.1635, binary linear error correcting code r...
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Discussion

# %% [markdown]
# ### Best LDA Model

# %%
print(f"Best LDA model:\n{best_lda_model}")
# Out:
# Best LDA model:
# {'num_topics': 15, 'model': LatentDirichletAllocation(doc_topic_prior=0.5, n_components=15, random_state=42,
#                           topic_word_prior=0.1), 'perplexity': 2324.4676980942677, 'word_topic_table':                     Topic1              Topic2              Topic3  \
# Word1     (0.0153, energy)    (0.0667, system)     (0.0179, graph)
# Word2       (0.0118, mass)   (0.0258, control)  (0.0168, function)
# Word3      (0.0098, model)     (0.0221, power)    (0.0136, number)
# Word4   (0.0092, spectrum)     (0.017, design)     (0.0132, bound)
# Word5       (0.0082, star)     (0.0102, paper)   (0.0115, lattice)
# Word6     (0.0061, galaxy)  (0.0097, proposed)      (0.011, model)
# Word7   (0.0057, emission)     (0.009, energy)    (0.0109, result)
# Word8    (0.0056, cluster)     (0.0083, state)      (0.0081, show)
# Word9     (0.0055, result)   (0.0073, circuit)    (0.0081, random)
# Word10      (0.0055, data)     (0.0071, based)      (0.0078, tree)
#
#                     Topic4                  Topic5                 Topic6  \
# Word1     (0.0298, method)     (0.0487, algorithm)     (0.0109, research)
# Word2      (0.0139, model)       (0.0335, problem)        (0.0094, paper)
# Word3      (0.0118, image)          (0.0139, time)         (0.0063, year)
# Word4       (0.011, based)        (0.0121, method)      (0.0063, science)
# Word5       (0.011, using)         (0.011, matrix)  (0.0063, development)
# Word6   (0.0107, proposed)       (0.0099, optimal)         (0.006, study)
# Word7   (0.0106, approach)   (0.0093, performance)          (0.0057, new)
# Word8     (0.0102, result)  (0.0091, optimization)       (0.0053, social)
# Word9     (0.01, learning)      (0.0086, approach)       (0.0051, physic)
# Word10   (0.0093, feature)          (0.0079, show)      (0.0049, student)
#
#                        Topic7                 Topic8                 Topic9  \
# Word1          (0.0179, data)      (0.0387, quantum)         (0.0212, cell)
# Word2          (0.0122, user)       (0.0318, system)        (0.0177, model)
# Word3   (0.0112, application)        (0.0297, state)      (0.0108, protein)
# Word4          (0.0093, code)      (0.0251, channel)         (0.0069, gene)
# Word5   (0.0086, information)        (0.0097, field)      (0.0067, process)
# Word6         (0.0086, paper)     (0.0097, particle)     (0.006, mechanism)
# Word7        (0.0083, system)     (0.009, classical)      (0.0059, dynamic)
# Word8      (0.0071, software)     (0.0084, capacity)    (0.0054, molecular)
# Word9          (0.0062, tool)  (0.0084, information)  (0.0053, interaction)
# Word10       (0.006, network)          (0.0083, two)     (0.0053, molecule)
#
#                        Topic10                Topic11              Topic12  \
# Word1          (0.0314, model)        (0.0121, field)     (0.0192, theory)
# Word2   (0.0194, distribution)     (0.0098, magnetic)    (0.0182, network)
# Word3           (0.0168, data)        (0.0083, phase)    (0.0137, dynamic)
# Word4         (0.0154, method)      (0.0083, surface)      (0.0105, agent)
# Word5        (0.0137, network)  (0.0072, temperature)   (0.0084, behavior)
# Word6      (0.0121, parameter)        (0.007, effect)       (0.008, model)
# Word7          (0.0083, error)    (0.0066, frequency)  (0.0073, structure)
# Word8       (0.0082, estimate)     (0.0061, electron)    (0.0068, pattern)
# Word9     (0.0078, estimation)          (0.006, wave)   (0.0064, analysis)
# Word10   (0.0077, probability)          (0.006, mode)      (0.0063, study)
#
#                   Topic13              Topic14                 Topic15
# Word1     (0.0184, space)      (0.0184, model)      (0.0343, equation)
# Word2     (0.0176, group)      (0.016, market)       (0.022, solution)
# Word3        (0.011, set)      (0.0126, price)         (0.0126, model)
# Word4   (0.0109, algebra)       (0.0116, risk)     (0.0107, nonlinear)
# Word5    (0.0096, result)       (0.0091, game)        (0.0098, method)
# Word6     (0.0094, class)   (0.0089, strategy)        (0.0094, theory)
# Word7     (0.0088, prove)        (0.008, show)     (0.0086, numerical)
# Word8      (0.0087, show)       (0.0069, time)  (0.0082, differential)
# Word9     (0.0086, paper)    (0.0064, process)          (0.008, field)
# Word10  (0.0083, theorem)  (0.0063, financial)          (0.0072, case)  , 'doc_topic_table':                                                  Topic1  \
# Doc1  (0.9421, discus xray property radio source det...
# Doc2  (0.9392, model disk galaxy formation commonly ...
# Doc3  (0.9391, present high resolution measurement n...
# Doc4  (0.9384, black hole binary transient undergo d...
# Doc5  (0.9383, compare spectral property short long ...
#
#                                                  Topic2  \
# Doc1  (0.889, paper low power low area array multipl...
# Doc2  (0.8704, onchip voltage regulation using distr...
# Doc3  (0.8684, paper proposes lowpower energy effici...
# Doc4  (0.8553, ieee ongoing revision ieee floating p...
# Doc5  (0.8448, considering control problem nonlinear...
#
#                                                  Topic3  \
# Doc1  (0.8657, total coloring graph coloring vertex ...
# Doc2  (0.8605, study dynamical property random trans...
# Doc3  (0.8461, study numerically paramagnetic phase ...
# Doc4  (0.8399, investigate localization two interact...
# Doc5  (0.832, new graphical method developed calcula...
#
#                                                  Topic4  \
# Doc1  (0.9278, utterance contains speech multiple la...
# Doc2  (0.9263, propose method zeroresource domain ad...
# Doc3  (0.9253, work propose new approach language id...
# Doc4  (0.9236, investigate novel crosslingual multis...
# Doc5  (0.9213, speaker recognition performance emoti...
#
#                                                  Topic5  \
# Doc1  (0.8684, paper present analyze new set lowrank...
# Doc2  (0.8625, novel algorithm proposed candecomppar...
# Doc3  (0.8493, matrix tensor completion aim recover ...
# Doc4  (0.8474, recent study sparse modeling nonconve...
# Doc5  (0.8405, attractiveness canonical polyadic ten...
#
#                                                  Topic6  \
# Doc1  (0.9405, leo goodman born august new york city...
# Doc2  (0.9194, george roussas born city marmara cent...
# Doc3  (0.9179, tadeusz calinski born poznan poland d...
# Doc4  (0.909, present two program address need bette...
# Doc5  (0.9053, harry martz born june grew cumberland...
#
#                                                  Topic7  \
# Doc1  (0.9185, grid based system require database ac...
# Doc2  (0.9126, pool project common persistency frame...
# Doc3  (0.9097, paper introduces writeoncereadmany xm...
# Doc4  (0.8978, information retrieval distributed het...
# Doc5  (0.897, alien alice environment gridlike syste...
#
#                                                  Topic8  \
# Doc1  (0.8915, wideband fading channel considered ca...
# Doc2  (0.8915, wideband fading channel considered ca...
# Doc3  (0.8128, multiple transmit antenna downlink ch...
# Doc4  (0.8128, multiple transmit antenna downlink ch...
# Doc5  (0.8066, shown mutual information curve coded ...
#
#                                                  Topic9  \
# Doc1  (0.9367, experimental evidence suggests foldin...
# Doc2  (0.921, kinesin motor protein destabilize micr...
# Doc3  (0.9208, zincfingers widely exist eukaryotic c...
# Doc4  (0.9162, development tumor known result accumu...
# Doc5  (0.9159, leishmania lipophosphoglycan molecule...
#
#                                                 Topic10  \
# Doc1  (0.9128, consider class semiparametric regress...
# Doc2  (0.9128, consider class semiparametric regress...
# Doc3  (0.9034, consider inference procedure conditio...
# Doc4  (0.8952, wang tchetgen tchetgen studied identi...
# Doc5  (0.8918, paper considers panel data model cond...
#
#                                                 Topic11  \
# Doc1  (0.9163, analysis alfven wave generation assoc...
# Doc2  (0.9113, paper examine suprathermal ion measur...
# Doc3  (0.9107, recent result van allen probe mission...
# Doc4  (0.9088, present first observation large ampli...
# Doc5  (0.9037, convection inside magnetosphere regar...
#
#                                                 Topic12  \
# Doc1  (0.8656, present study focused effect trunk ex...
# Doc2  (0.8198, many complex human natural phenomenon...
# Doc3  (0.7926, aim present study ass effect plantarf...
# Doc4  (0.7921, purpose present experiment investigat...
# Doc5  (0.7482, separate study reported postural cont...
#
#                                                 Topic13  \
# Doc1  (0.948, hausdorff topological group gtau calle...
# Doc2  (0.942, prove algebraic hypersurfaces defined ...
# Doc3  (0.9354, topological group gmu class mathcal m...
# Doc4  (0.9299, thesis develop cohomology diagram alg...
# Doc5  (0.9291, previous work citeas showed attach po...
#
#                                                 Topic14  \
# Doc1  (0.9064, propose model credit market random de...
# Doc2  (0.9003, develop finite horizon continuous tim...
# Doc3  (0.8983, study robust double auction mechanism...
# Doc4  (0.8879, study impact central clearing overthe...
# Doc5  (0.8801, consider partially asymmetric threepl...
#
#                                                 Topic15
# Doc1  (0.8645, present special solution discrete pai...
# Doc2  (0.8446, advection equation basis mathematical...
# Doc3  (0.8441, socalled direct approach separation v...
# Doc4  (0.8404, study class quadratically nonlinear w...
# Doc5  (0.8382, extending clarksonkruskals direct sim...  }

# %% [markdown]
# Here are the features of the best LDA model:
# - `Number of Topics`: 15
# - `Perplexity`: 2324.47
# Among the LDA models trained, this model got the lowest perplexity. However, perplexity is not the only basis of determining whether it is the best data. Looking at the word-topic and document-topic tables, the associated words and documents show that the topics are interpretable.
#
# Abstract Topics for the LDA Model:
# 1. Topic 1:
#
# - **Dominant Words:** energy, mass, spectrum, star, galaxy, emission
# - **Possible Topic:** Astrophysics and Cosmology
# - **Description:** Focuses on physical and astronomical phenomena, such as energy, celestial masses, and the electromagnetic spectrum, often relating to the study of stars, galaxies, and cosmic emission.
#
# 2. Topic 2:
#
# - **Dominant Words:** system, control, power, design, circuit
# - **Possible Topic:** Electrical Engineering and Control Systems
# - **Description:** Covers systems engineering, including circuit design, power management, and control mechanisms in various applications.
#
# 3. Topic 3:
#
# - **Dominant Words:** graph, function, number, bound, lattice
# - **Possible Topic:** Mathematics and Graph Theory
# - **Description:** This topic deals with mathematical structures, such as graphs and lattices, as well as functions and numerical analysis.
#
# 4. Topic 4:
#
# - **Dominant Words:** method, model, imaged, based, using
# - **Possible Topic:** Image Processing and Machine Learning
# - **Description:** Focuses on developing and applying computational methods for image-based learning, leveraging models, approaches, and features for achieving results in areas like computer vision and pattern recognition.
#
# 5. Topic 5:
#
# - **Dominant Words:** algorithm, problem, matrix, time, performance
# - **Possible Topic:** Algorithms and Optimization
# - **Description:** Explores the properties of quantum fields, particle states, and energy at microscopic levels, fundamental to physics.

# %%
lda_model = best_lda_model['model']
lda_model
# Out:
# LatentDirichletAllocation(doc_topic_prior=0.5, n_components=15, random_state=42,
#                           topic_word_prior=0.1)

# %%
lda_plot = pyLDAvis.sklearn.prepare(lda_model, count_data, count_vectorizer)
pyLDAvis.display(lda_plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5212\510838869.py in <module>
# ----> 1 lda_plot = pyLDAvis.sklearn.prepare(lda_model, count_data, count_vectorizer)
#       2 pyLDAvis.display(lda_plot)
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pyLDAvis\sklearn.py in prepare(lda_model, dtm, vectorizer, **kwargs)
#      93     """
#      94     opts = fp.merge(_extract_data(lda_model, dtm, vectorizer), kwargs)
# ---> 95     return pyLDAvis.prepare(**opts)
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pyLDAvis\_prepare.py in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics)
#     396    term_frequency = np.sum(term_topic_freq, axis=0)
#     397
# --> 398    topic_info         = _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs)
#     399    token_table        = _token_table(topic_info, term_topic_freq, vocab, term_frequency)
#     400    topic_coordinates = _topic_coordinates(mds, topic_term_dists, topic_proportion)
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pyLDAvis\_prepare.py in _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs)
#     228    default_term_info  = pd.DataFrame({'saliency': saliency, 'Term': vocab, \
#     229                                       'Freq': term_frequency, 'Total': term_frequency, \
# --> 230                                       'Category': 'Default'}). \
#     231       sort_values(by='saliency', ascending=False). \
#     232       head(R).drop('saliency', 1)
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      54
#      55     # don't force copy because getting jammed in an ndarray anyway
# ---> 56     arrays = _homogenize(arrays, index, dtype)
#      57
#      58     # from BlockManager perspective
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     275                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
#     276             val = sanitize_array(val, index, dtype=dtype, copy=False,
# --> 277                                  raise_cast_failure=False)
#     278
#     279         homogenized.append(val)
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     640
#     641             subarr = construct_1d_arraylike_from_scalar(
# --> 642                 value, len(index), dtype)
#     643
#     644         else:
#
# c:\Users\abiga\anaconda3\envs\UnsupervisedML\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1185                 value = to_str(value)
#    1186
# -> 1187         subarr = np.empty(length, dtype=dtype)
#    1188         subarr.fill(value)
#    1189
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %% [markdown]
# ### Best NMF Model

# %%
print(f"Best NMF model:\n{best_nmf_model}")
# Out:
# Best NMF model:
# {'num_topics': 30, 'reconstruction_error': 6.623565181562852e-05, 'sparsity_W': 0.43985675281445186, 'sparsity_H': 0.31946327885233033, 'word_topic_table':                        Topic1                Topic2                 Topic3  \
# Word1          (0.0128, data)         (0.0171, set)        (0.0167, phase)
# Word2           (0.006, user)     (0.0151, theorem)  (0.0122, temperature)
# Word3   (0.0052, information)       (0.0125, proof)   (0.0106, transition)
# Word4   (0.0048, application)       (0.0111, prove)        (0.0093, state)
# Word5      (0.0043, research)         (0.0097, let)       (0.007, lattice)
# Word6       (0.004, analysis)  (0.0095, polynomial)        (0.006, effect)
# Word7      (0.0039, software)        (0.0087, ring)      (0.0056, density)
# Word8      (0.0038, approach)      (0.0086, finite)         (0.0055, wave)
# Word9          (0.0036, tool)      (0.0086, number)         (0.0053, spin)
# Word10       (0.0035, design)      (0.0084, result)  (0.0051, interaction)
#
#                         Topic4                Topic5                 Topic6  \
# Word1       (0.0769, equation)       (0.0676, model)       (0.0818, system)
# Word2       (0.0485, solution)       (0.016, market)       (0.018, dynamic)
# Word3   (0.0176, differential)        (0.015, price)    (0.0131, nonlinear)
# Word4      (0.0108, nonlinear)  (0.0093, volatility)         (0.0107, type)
# Word5           (0.0087, wave)      (0.0082, option)    (0.0105, dynamical)
# Word6         (0.008, problem)        (0.0067, risk)      (0.0066, complex)
# Word7      (0.0078, numerical)     (0.0059, pricing)        (0.0065, agent)
# Word8      (0.0067, condition)       (0.0059, asset)  (0.0059, hamiltonian)
# Word9       (0.0057, boundary)  (0.0058, stochastic)  (0.0055, interaction)
# Word10   (0.0056, schrodinger)   (0.0056, parameter)   (0.0048, integrable)
#
#                      Topic7                  Topic8               Topic9  \
# Word1     (0.0964, network)     (0.0931, algorithm)      (0.077, method)
# Word2        (0.0163, node)       (0.0083, problem)   (0.0111, proposed)
# Word3      (0.0134, neural)    (0.0083, complexity)   (0.0086, approach)
# Word4      (0.0088, social)          (0.0071, time)      (0.0084, based)
# Word5   (0.0057, structure)    (0.0062, polynomial)       (0.008, using)
# Word6    (0.0055, topology)     (0.0058, efficient)  (0.0076, numerical)
# Word7        (0.0051, link)       (0.0057, present)       (0.0064, used)
# Word8     (0.0043, dynamic)        (0.0054, search)        (0.0062, new)
# Word9     (0.0042, traffic)  (0.0054, optimization)  (0.0058, technique)
# Word10    (0.0042, routing)   (0.0054, performance)      (0.005, signal)
#
#                          Topic10  ...                 Topic21  \
# Word1            (0.1327, group)  ...      (0.1246, function)
# Word2         (0.0201, subgroup)  ...       (0.0116, formula)
# Word3   (0.0122, representation)  ...      (0.0086, integral)
# Word4           (0.0115, finite)  ...   (0.0082, correlation)
# Word5             (0.0102, free)  ...         (0.0071, value)
# Word6           (0.0093, action)  ...      (0.0069, variable)
# Word7          (0.0087, abelian)  ...    (0.0068, polynomial)
# Word8            (0.0078, class)  ...          (0.0062, term)
# Word9              (0.0077, lie)  ...  (0.006, approximation)
# Word10         (0.007, finitely)  ...    (0.0058, derivative)
#
#                     Topic22                   Topic23  \
# Word1        (0.0163, star)          (0.1244, matrix)
# Word2        (0.0145, mass)      (0.0153, eigenvalue)
# Word3       (0.014, galaxy)      (0.0144, polynomial)
# Word4     (0.0094, cluster)         (0.0087, element)
# Word5    (0.0069, emission)      (0.0084, covariance)
# Word6      (0.0065, planet)           (0.008, random)
# Word7        (0.0063, disk)            (0.0077, rank)
# Word8        (0.0058, xray)          (0.0075, sparse)
# Word9     (0.0058, stellar)  (0.0068, multiplication)
# Word10  (0.0056, formation)           (0.0068, entry)
#
#                          Topic24             Topic25                Topic26  \
# Word1            (0.0706, image)    (0.0442, energy)     (0.1079, category)
# Word2   (0.0074, reconstruction)      (0.0146, beam)    (0.0197, structure)
# Word3          (0.0071, imaging)  (0.0096, electron)      (0.016, monoidal)
# Word4          (0.0067, quality)  (0.0087, particle)       (0.0156, object)
# Word5        (0.0066, technique)    (0.008, section)     (0.0131, homotopy)
# Word6            (0.0065, noise)  (0.0077, detector)     (0.0121, functors)
# Word7         (0.0061, proposed)     (0.0075, cross)       (0.012, functor)
# Word8            (0.0058, pixel)       (0.0066, mev)       (0.0108, theory)
# Word9      (0.0054, compression)    (0.0066, proton)       (0.0101, module)
# Word10      (0.0052, processing)  (0.0064, measured)  (0.0097, equivalence)
#
#                     Topic27                Topic28                Topic29  \
# Word1    (0.0495, manifold)     (0.1038, operator)    (0.1479, withdrawn)
# Word2     (0.0293, surface)        (0.0189, state)         (0.097, paper)
# Word3   (0.019, symplectic)     (0.0173, language)       (0.0896, author)
# Word4   (0.0129, structure)     (0.0131, spectrum)          (0.0246, due)
# Word5   (0.0119, invariant)   (0.0121, eigenvalue)        (0.0169, error)
# Word6       (0.0103, curve)     (0.0116, spectral)  (0.0142, publication)
# Word7      (0.0102, bundle)    (0.0082, automaton)    (0.011, submission)
# Word8     (0.0093, complex)  (0.0075, selfadjoint)      (0.0095, version)
# Word9         (0.0085, map)    (0.0073, potential)        (0.0077, arxiv)
# Word10    (0.0084, compact)  (0.0072, schrodinger)  (0.0053, preliminary)
#
#                      Topic30
# Word1         (0.0775, code)
# Word2        (0.0544, bound)
# Word3        (0.0183, upper)
# Word4         (0.016, lower)
# Word5     (0.0147, decoding)
# Word6        (0.0135, error)
# Word7       (0.0088, binary)
# Word8   (0.0085, complexity)
# Word9         (0.0078, ldpc)
# Word10      (0.0066, length)
#
# [10 rows x 30 columns], 'doc_topic_table':                                                  Topic1  \
# Doc1  (0.0389, web community introduced set standard...
# Doc2  (0.0382, current research biology heavily depe...
# Doc3  (0.0368, year hera machine experiment performe...
# Doc4  (0.0341, integrating open data source yield hi...
# Doc5  (0.034, data security major issue webbased app...
#
#                                                  Topic2  \
# Doc1  (0.0705, proof set real number denumerable given)
# Doc2  (0.0687, prove theorem following form asubsete...
# Doc3  (0.0677, note give alternative proof following...
# Doc4  (0.0655, let ideal commutative noetherian ring...
# Doc5  (0.0651, real part hinftybt dense linftytrbt j...
#
#                                                  Topic3  \
# Doc1  (0.1178, paper phase diagram polar spin bose g...
# Doc2  (0.1171, study twodimensional model quenched r...
# Doc3  (0.1043, phase diagram metal variable carrier ...
# Doc4  (0.1018, effect uncompensated gav codoping str...
# Doc5  (0.1002, finite temperature phase diagram higg...
#
#                                                  Topic4  \
# Doc1  (0.1055, general helfrich shape equation deter...
# Doc2  (0.104, define system dynamical differential e...
# Doc3  (0.1023, solving diffusion problem common cons...
# Doc4  (0.1013, general lattice boltzmann model propo...
# Doc5  (0.0956, extended system governed partial diff...
#
#                                                  Topic5  \
# Doc1  (0.1155, propose new approach model compositio...
# Doc2  (0.1064, aim paper present describe simlab sim...
# Doc3  (0.1048, paper develop stochastic volatility p...
# Doc4  (0.1039, parallel programming model exist abst...
# Doc5  (0.1018, computer simulation amphiphilic syste...
#
#                                                  Topic6  \
# Doc1  (0.1462, one may define complex system system ...
# Doc2  (0.1217, system approach first step towards an...
# Doc3  (0.1163, system system differ traditional syst...
# Doc4  (0.1138, principle natural system biological e...
# Doc5  (0.1106, using set heterogeneous competing sys...
#
#                                                  Topic7  \
# Doc1  (0.1393, many real network understood two comp...
# Doc2  (0.1282, yehuda vardi introduced term network ...
# Doc3  (0.1267, goal determine structural difference ...
# Doc4  (0.1249, analogous biological sequence compari...
# Doc5  (0.1234, social network grows period time form...
#
#                                                  Topic8  \
# Doc1  (0.1096, study computational aspect nonparamet...
# Doc2  (0.0945, gvw algorithm presented gao signature...
# Doc3  (0.0902, signaturebased algorithm popular kind...
# Doc4  (0.0896, famous algorithm computing grobner ba...
# Doc5  (0.0888, give sublineartime approximation algo...
#
#                                                  Topic9  \
# Doc1  (0.0938, propose new method preconditioning ka...
# Doc2  (0.0868, study present method measure change t...
# Doc3  (0.0867, present novel method calculation frac...
# Doc4  (0.0861, overview article present several meth...
# Doc5  (0.085, introduce new iterative rootfinding me...
#
#                                                 Topic10  ...  \
# Doc1  (0.1671, prove permutation group different fin...  ...
# Doc2  (0.1613, paper mainly concerned study polariza...  ...
# Doc3  (0.1613, paper mainly concerned study polariza...  ...
# Doc4  (0.1592, study group homotopy class self map c...  ...
# Doc5  (0.1579, various descending chain subgroup fin...  ...
#
#                                                 Topic21  \
# Doc1  (0.1973, paper small survey presented eighteen...
# Doc2  (0.1642, paper propose study family sparsityin...
# Doc3  (0.1573, realvalued nonnegative logconcave fun...
# Doc4  (0.1488, treatise investigates holomorphic fun...
# Doc5  (0.1467, paper consider situation given logica...
#
#                                                 Topic22  \
# Doc1  (0.1435, study stellar mass assembly spiderweb...
# Doc2  (0.1428, nuclear star cluster nsc located phot...
# Doc3  (0.1371, present iram plateau bure interferome...
# Doc4  (0.1339, present comprehensive analysis stella...
# Doc5  (0.1333, present observation massive star clus...
#
#                                                 Topic23  \
# Doc1  (0.1884, ntimes matrix certain signsymmetric s...
# Doc2  (0.1863, assembled java package known matrixpa...
# Doc3  (0.1849, generalized inversion block matrix ob...
# Doc4  (0.1794, show matrix hermitian positive semide...
# Doc5  (0.179, nystrom method routinely used outofsam...
#
#                                                 Topic24  \
# Doc1  (0.2393, image compression play important role...
# Doc2  (0.2341, powerful deep network architecture ge...
# Doc3  (0.2233, paper attempt improve quality modific...
# Doc4  (0.2215, due increasing requirement transmissi...
# Doc5  (0.2136, advancement image capturing device im...
#
#                                                 Topic25  \
# Doc1  (0.1566, study reaction performed energy range...
# Doc2  (0.1457, using fopi detector gsi darmstadt exc...
# Doc3  (0.1388, measurement dielectron production col...
# Doc4  (0.1265, partition decay energy kinetic energy...
# Doc5  (0.12, event large rapidity gap total transver...
#
#                                                 Topic26  \
# Doc1  (0.2217, construction kleisli object category ...
# Doc2  (0.2044, paper work detail closed multicategor...
# Doc3  (0.2008, popescugabriel theorem state grothend...
# Doc4  (0.1939, give explicit construction category o...
# Doc5  (0.1931, generalize notion monetary value meas...
#
#                                                 Topic27  \
# Doc1  (0.1902, describe algorithm enabled give compl...
# Doc2  (0.1861, kcontact manifold smooth manifold con...
# Doc3  (0.1784, show certain class contact manifold a...
# Doc4  (0.1751, first part paper begin study polysymp...
# Doc5  (0.172, question whether riemannian manifold g...
#
#                                                 Topic28  \
# Doc1  (0.2021, spectral problem vzpsizpsi considered...
# Doc2  (0.1984, indefinite sturmliouville operator sg...
# Doc3  (0.187, construct family bispectral difference...
# Doc4  (0.1792, regular operator hilbert cmodule defi...
# Doc5  (0.1702, generalizing algebra motioninvariant ...
#
#                                Topic29  \
# Doc1  (0.3349, paper withdrawn author)
# Doc2  (0.3349, paper withdrawn author)
# Doc3  (0.3349, paper withdrawn author)
# Doc4  (0.3349, paper withdrawn author)
# Doc5  (0.3349, paper withdrawn author)
#
#                                                 Topic30
# Doc1  (0.1705, upper lower bound error probability l...
# Doc2  (0.1705, upper lower bound error probability l...
# Doc3  (0.1649, derive bound asymptotic density parit...
# Doc4  (0.1649, derive bound asymptotic density parit...
# Doc5  (0.1635, binary linear error correcting code r...
#
# [5 rows x 30 columns]}

# %% [markdown]
# Here are the features of the best NMF model:
# - `Number of Topics`: 30
# - `Reconstruction Error`: 6.623565181562852e-05
# This low error indicates a strong ability to reconstruct the original data from the model’s components, making it useful for tasks requiring detailed analysis.
# - `Sparsity (W)`: 0.44 (document-topic sparsity).
# This indicates that most documents are represented by a limited number of topics, leading to focused topic distributions.
# - `Sparsity (H)`: 0.32 (word-topic sparsity).
# This shows that each topic is defined by a smaller subset of the vocabulary, potentially making the topics more interpretable.
#
# Abstract Topics for the NMF Model:
# 1. Topic 1:
#
# - **Dominant Words:** data, user, information, application, research
# - **Possible Topic:** Data Science and Applications
# - **Description:** Focuses on the use of data and software tools to analyze, design, and apply methods in information-driven research and development.
#
# 2. Topic 2:
#
# - **Dominant Words:** set, theorem, proof, prove, let
# - **Possible Topic:** Mathematics and Theoretical Proofs
# - **Description:** Explores mathematical structures and theories, including set theory, polynomial analysis, and number theory, with an emphasis on theorems and proofs.
#
# 3. Topic 3:
#
# - **Dominant Words:** phase, temperature, transition, state, lattice
# - **Possible Topic:** Thermodynamics and Material Science
# - **Description:** Examines physical phenomena related to phase transitions, thermal properties, and lattice structures in materials.
#
# 4. Topic 4:
#
# - **Dominant Words:** equation, solution, differential, nonlinear, wave
# - **Possible Topic:** Differential Equations and Mathematical Modeling
# - **Description:** Centers around solving mathematical equations (e.g., Schrodinger equation) with applications in physics, engineering, and numerical modeling.
#
# 5. Topic 5:
#
# - **Dominant Words:** model, market, price, volatility, option
# - **Possible Topic:** Financial Modeling and Risk Analysis
# - **Description:** Focuses on mathematical and statistical models for financial markets, including pricing, volatility analysis, and risk management.

# %% [markdown]
# ### Comparison Between LDA and NMF:
# 1. Interpretability:
# - LDA topics are well-separated and interpretable, focusing on high-level themes like energy, systems, and algorithms.
# - NMF provides fine-grained topics, but their interpretability might require domain-specific knowledge.
#
# 2. Performance:
#
# - LDA's perplexity (2324.47) is relatively low, indicating a better generalization for unseen data.
# - NMF has a significantly lower reconstruction error, suggesting it reconstructs the document-term matrix more accurately.
#
# 3. Sparsity:
#
# - NMF has higher sparsity, which can lead to more interpretable topics but may miss overlapping themes.
# - LDA captures overlapping word usage better due to its probabilistic nature.
#
# 4. Flexibility:
#
# - LDA provides overlapping word distributions across topics, making it better for capturing nuanced relationships.
# - NMF enforces non-negativity, ensuring that topics remain non-overlapping and concise.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# After evaluating both the LDA and NMF models, the **NMF model** is chosen as the better fit for this use case. The dataset's structure, which includes subtopics within general topics, aligns more effectively with the interpretability and coherence of the topics generated by the **NMF model**. Here’s why the NMF model was selected:
#
# 1. Quantitative Reasons:
# - Reconstruction Error: The NMF model demonstrated a significantly lower reconstruction error, indicating a better fit to the data compared to the LDA model's perplexity score.
# - Sparsity: The sparsity metrics for the NMF model highlight its ability to provide compact and interpretable representations of topics, reducing overlap and improving clarity.
# 2. Qualitative Reasons:
# - Coherence of Topics: The NMF model produced topics with well-defined dominant words that clearly align with the dataset's general themes and subtopics, such as "Data Science and Applications" and "Thermodynamics and Material Science."
# - Alignment with Dataset Structure: The subtopic-focused nature of the dataset favors NMF's deterministic approach to topic generation, resulting in more granular and interpretable topic clusters compared to the probabilistic LDA model.
# - Stakeholder Usability: The topics derived from the NMF model provide actionable insights and categorizations that align with the stakeholders' goals of extracting well-defined subtopics for further analysis or application.
# 3. Limitations of the LDA Model:
# While the LDA model is effective in probabilistically identifying broader themes, its topics lacked the granularity and coherence required for this dataset's subtopic-focused structure. This reduced its usefulness for stakeholders who rely on precise topic delineations.
#
# The NMF model effectively addresses the use case by providing granular, coherent, and interpretable topics that align with the dataset’s structure. This ensures that stakeholders can utilize the topics meaningfully for further categorization, analysis, or reporting.
